# %% [markdown]
# ## Imports

# %%
import os
import shutil
import subprocess
import pandas as pd

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Get ADPD Metadata

# %%
metadata = pd.read_excel('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/190215_Brain-ControlsOnly_Metadata_Merged.xlsx')
display(metadata)
# Out:
#                                          OldName  \
# 0    PD_00_38_CTRL_CAUD_X014_S01_L001_B1_T1_P025
# 1    PD_00_38_CTRL_CAUD_X014_S01_L002_B1_T2_P028
# 2    PD_00_38_CTRL_HIPP_X002_S11_L045_B1_T1_P002
# 3    PD_00_38_CTRL_HIPP_X002_S11_L046_B1_T2_P003
# 4    PD_00_38_CTRL_MDFG_X007_S04_L055_B1_T1_P014
# ..                                           ...
# 263  PD_16_32_CTRL_MDTG_X003_S04_L008_B1_T2_P003
# 264  PD_16_32_CTRL_PTMN_X019_S08_L039_B1_T1_P033
# 265  PD_16_32_CTRL_PTMN_X019_S08_L040_B1_T2_P030
# 266  PD_16_32_CTRL_SUNI_X007_S12_L071_B1_T1_P014
# 267  PD_16_32_CTRL_SUNI_X007_S12_L072_B1_T2_P012
#
#                                          NewName  \
# 0    PD_00_38_CTRL_CAUD_X014_S01_L001_B1_T1_P025
# 1    PD_00_38_CTRL_CAUD_X014_S01_L002_B1_T2_P028
# 2    PD_00_38_CTRL_HIPP_X002_S11_L045_B1_T1_P002
# 3    PD_00_38_CTRL_HIPP_X002_S11_L046_B1_T2_P003
# 4    PD_00_38_CTRL_MDFG_X007_S04_L055_B1_T1_P014
# ..                                           ...
# 263  PD_16_32_CTRL_MDTG_X003_S04_L008_B1_T2_P003
# 264  PD_16_32_CTRL_PTMN_X019_S08_L039_B1_T1_P033
# 265  PD_16_32_CTRL_PTMN_X019_S08_L040_B1_T2_P030
# 266  PD_16_32_CTRL_SUNI_X007_S12_L071_B1_T1_P014
# 267  PD_16_32_CTRL_SUNI_X007_S12_L072_B1_T2_P012
#
#                                     HarmonizedName  \
# 0    CTRL_CAUD_PD_00x38xx_X014_S01_L001_B1_T1_P025
# 1    CTRL_CAUD_PD_00x38xx_X014_S01_L002_B1_T2_P028
# 2    CTRL_HIPP_PD_00x38xx_X002_S11_L045_B1_T1_P002
# 3    CTRL_HIPP_PD_00x38xx_X002_S11_L046_B1_T2_P003
# 4    CTRL_MDFG_PD_00x38xx_X007_S04_L055_B1_T1_P014
# ..                                             ...
# 263  CTRL_SMTG_PD_16x32xx_X003_S04_L008_B1_T2_P003
# 264  CTRL_PTMN_PD_16x32xx_X019_S08_L039_B1_T1_P033
# 265  CTRL_PTMN_PD_16x32xx_X019_S08_L040_B1_T2_P030
# 266  CTRL_SUNI_PD_16x32xx_X007_S12_L071_B1_T1_P014
# 267  CTRL_SUNI_PD_16x32xx_X007_S12_L072_B1_T2_P012
#
#                                                    Bam   Contrast  Type Group  \
# 0    /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_CAUD  CTRL  CTRL
# 1    /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_CAUD  CTRL  CTRL
# 2    /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_HIPP  CTRL  CTRL
# 3    /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_HIPP  CTRL  CTRL
# 4    /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_MDFG  CTRL  CTRL
# ..                                                 ...        ...   ...   ...
# 263  /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_MDTG  CTRL  CTRL
# 264  /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_PTMN  CTRL  CTRL
# 265  /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_PTMN  CTRL  CTRL
# 266  /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_SUNI  CTRL  CTRL
# 267  /oak/stanford/groups/howchang/users/mcorces/PD...  CTRL_SUNI  CTRL  CTRL
#
#     Region RegionMod PatientID  ... xxx.CONTRIBUTING_NP_DX  \
# 0     CAUD      CAUD     00_38  ...                    NaN
# 1     CAUD      CAUD     00_38  ...                    NaN
# 2     HIPP      HIPP     00_38  ...                    NaN
# 3     HIPP      HIPP     00_38  ...                    NaN
# 4     MDFG      MDFG     00_38  ...                    NaN
# ..     ...       ...       ...  ...                    ...
# 263   MDTG      SMTG     16_32  ...                    NaN
# 264   PTMN      PTMN     16_32  ...                    NaN
# 265   PTMN      PTMN     16_32  ...                    NaN
# 266   SUNI      SUNI     16_32  ...                    NaN
# 267   SUNI      SUNI     16_32  ...                    NaN
#
#     xxx.Interval between death and last MMSE xxx.ch_lastCasiScore  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
# ..                                       ...                  ...
# 263                                      NaN                  NaN
# 264                                      NaN                  NaN
# 265                                      NaN                  NaN
# 266                                      NaN                  NaN
# 267                                      NaN                  NaN
#
#     xxx.ch_lastCasiDate xxx.micro_AmyloidAngiopathyOccipitalLobe_ID  \
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
# 2                   NaN                                         NaN
# 3                   NaN                                         NaN
# 4                   NaN                                         NaN
# ..                  ...                                         ...
# 263                 NaN                                         NaN
# 264                 NaN                                         NaN
# 265                 NaN                                         NaN
# 266                 NaN                                         NaN
# 267                 NaN                                         NaN
#
#     xxx.GE_atherosclerosis_ID xxx.calc_A xxx.calc_B xxx.C xxx.CognitiveStatus
# 0                         NaN        NaN        NaN   NaN                 NaN
# 1                         NaN        NaN        NaN   NaN                 NaN
# 2                         NaN        NaN        NaN   NaN                 NaN
# 3                         NaN        NaN        NaN   NaN                 NaN
# 4                         NaN        NaN        NaN   NaN                 NaN
# ..                        ...        ...        ...   ...                 ...
# 263                       NaN        NaN        NaN   NaN                 NaN
# 264                       NaN        NaN        NaN   NaN                 NaN
# 265                       NaN        NaN        NaN   NaN                 NaN
# 266                       NaN        NaN        NaN   NaN                 NaN
# 267                       NaN        NaN        NaN   NaN                 NaN
#
# [268 rows x 108 columns]

# %% [markdown]
# ## Get Bams for each Patient

# %%
display(metadata['PatientID'].unique())
patients = list(metadata['PatientID'].unique())
# Out:
# array(['00_38', '01_31', '01_37', '03_15', '03_39', '03_41', '03_66',
#        '04_38', '05_16', '06_0615', '06_1516', '06_57', '07_1058',
#        '07_1144', '07_1287', '07_28', '08_0298', '08_0712', '08_90',
#        '09_1589', '09_35', '09_50', '10_0867', '11_0311', '11_0393',
#        '13_0038', '13_0962', '13_1226', '14_0380', '14_0513', '14_0586',
#        '14_0941', '14_1018', '14_1383', '15_1023', '15_1025', '15_78',
#        '16_10', '16_32'], dtype=object)

# %%
with open('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/ctrl_bams.txt') as infile:
    ctrl_bams = infile.readlines()
multi_bam_pats = []
for pat in patients:
    print(pat)
    patient_bams = []
    for bam in ctrl_bams:
        if pat in bam:
            patient_bams.append(bam)
    if len(patient_bams) > 1:
        multi_bam_pats.append(pat)
        patient_bams.sort()
        if not os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/input/' + pat):
            os.mkdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/input/' + pat)
        if not os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/output/' + pat):
            os.mkdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/output/' + pat)
        with open('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/bam_lists/' + pat + '_ctrl_bams.txt', 'w') as outfile:
            for bam in patient_bams:
                outfile.write(bam)
# Out:
# 00_38
# 01_31
# 01_37
# 03_15
# 03_39
# 03_41
# 03_66
# 04_38
# 05_16
# 06_0615
# 06_1516
# 06_57
# 07_1058
# 07_1144
# 07_1287
# 07_28
# 08_0298
# 08_0712
# 08_90
# 09_1589
# 09_35
# 09_50
# 10_0867
# 11_0311
# 11_0393
# 13_0038
# 13_0962
# 13_1226
# 14_0380
# 14_0513
# 14_0586
# 14_0941
# 14_1018
# 14_1383
# 15_1023
# 15_1025
# 15_78
# 16_10
# 16_32

# %% [markdown]
# ## Make Input Files

# %%
for pat in multi_bam_pats:
    print(pat)
    with open('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/bam_lists/' + pat + '_ctrl_bams.txt') as infile:
        pat_bams = [i.strip() for i in infile.readlines()]
        for bam in pat_bams:
            bam_name = bam.split('/')[10]
            #mpileup_cmd = 'sbatch --export=ALL -n 1 -t 1-0 -p akundaje --mail-type=ALL -J ' + bam_name + ' run_mpileup.sh ' + bam + ' ' + bam_name      
            #print(mpileup_cmd)
            #print("MPILEUP")
            #! {mpileup_cmd}
            #format_cmd = "zcat /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/pileup/" + bam_name + ".pileup.gz | awk -v OFS='\t' '{ if ($4>0 && $5 !~ /[^\^][<>]/ && $5 !~ /\+[0-9]+[ACGTNacgtn]+/ && $5 !~ /-[0-9]+[ACGTNacgtn]+/ && $5 !~ /[^\^]\*/) print $1,$2-1,$2,$3,$4,$5,$6}' | sortBed -i stdin | intersectBed -a stdin -b /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/snps/hg38_1KG_ADPD_snps.bed -wo | cut -f 1-7,11-14 | gzip > /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/pileup_beds/" + bam_name + ".pileup.bed.gz"
            #print(format_cmd)
            #print("FORMAT")
            #format_cmd = format_cmd.split()
            #ret = subprocess.call(format_cmd)
            #r_cmd = "R --vanilla --args /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/pileup_beds/" + bam_name + ".pileup.bed.gz < /users/soumyak/QuASAR/scripts/convertPileupToQuasar.R"
            #print(r_cmd)
            #print("R")
            #r_cmd = r_cmd.split()
            #ret = r_cmd.split()

# %%
for item in os.listdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/input/all'):
    pat = item.split('_')[2] + '_' + item.split('_')[3].split('.')[0]
    print(pat)
    shutil.move('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/input/all/' + item, '/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allele_bias/quasar/input/' + pat + '/')
# Out:
# 04_38
# 10_0867
# 14_0586
# 07_28
# 07_1287
# 10_0867
# 14_0586
# 14_0941
# 07_1287
# 09_1589
# 03_41
# 15_1023
# 11_0311
# 16_10
# 05_16
# 14_1018
# 03_41
# 06_1516
# 03_15
# 14_1383
# 13_1226
# 15_1023
# 03_39
# 13_0038
# 09_35
# 14_0941
# 13_0962
# 05_16
# 04_38
# 09_50
# 00_38
# 13_0038
# 06_1516
# 08_0298
# 00_38
# 16_32
# 05_16
# 07_1287
# 11_0393
# 03_15
# 09_35
# 15_78
# 11_0311
# 03_39
# 14_1383
# 14_0380
# 09_35
# 14_0380
# 10_0867
# 14_1383
# 15_1025
# 00_38
# 01_31
# 03_39
# 06_1516
# 14_1018
# 16_10
# 03_66
# 07_1144
# 15_1025
# 14_0513
# 04_38
# 09_50
# 03_15
# 16_32
# 07_1287
# 14_0380
# 09_50
# 00_38
# 03_41
# 03_66
# 03_39
# 07_1058
# 15_1025
# 15_1023
# 04_38
# 00_38
# 14_0586
# 09_1589
# 03_66
# 13_0962
# 15_1023
# 16_32
# 14_0513
# 15_1025
# 13_1226
# 07_1144
# 14_0513
# 14_0513
# 07_1144
# 15_78
# 04_38
# 09_50
# 09_35
# 14_0586
# 03_66
# 11_0393
# 13_0962
# 00_38
# 08_0712
# 07_1144
# 04_38
# 03_41
# 03_41
# 13_0038
# 14_0380
# 09_1589
# 13_0962
# 03_66
# 15_78
# 05_16
# 15_78
# 07_1058
# 05_16
# 01_31
# 16_32
# 11_0393
# 05_16
# 08_0712
# 08_0298
# 09_35
# 14_1018
# 14_1383
# 16_10
# 09_35
# 13_1226
# 03_39
# 11_0393
# 07_28
# 13_0038
# 15_78
# 16_32
# 07_1058
# 13_1226
# 10_0867
# 14_1018

# %%
genotype_example = pd.read_csv('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allelic_imbalance/quasar/output/00_38/genotypes.txt', sep='\t')
genotype_example.head()
# Out:
#     chr      pos0       pos        rsID   map.g0        map.g1         map.g2
# 0  chr1  39833522  39833523  rs17504495  0.99997  2.985130e-05   1.120785e-45
# 1  chr1  39878502  39878503   rs7516590  0.99997  3.000135e-05   5.011024e-44
# 2  chr1  39878995  39878996   rs7527412  1.00000  1.160375e-10  3.610483e-100
# 3  chr1  39883755  39883756  rs61781270  1.00000  2.019370e-14  8.808977e-164
# 4  chr1  39887779  39887780  rs61781272  1.00000  2.333275e-10   1.430093e-92

# %%
inference_example = pd.read_csv('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allelic_imbalance/quasar/output/00_38/CTRL_CAUD_00_38.inference.txt', sep='\t')
inference_example.head()
# Out:
#   annotations.rsID annotations.chr  annotations.pos0     betas  betas.se  \
# 0        rs7212019           chr17          78432471  1.514618  0.552973
# 1        rs1237999           chr11          86103987  2.514354  0.764788
# 2       rs11077365           chr17          78432411 -2.780313  0.716190
# 3        rs2693359           chr17          45584384  1.266519  0.645607
# 4       rs35860453            chr2         127108470 -0.958534  0.526701
#
#    pval2.het.ind.
# 0        0.006162
# 1        0.019190
# 2        0.025581
# 3        0.049792
# 4        0.068777

# %%
all_inf = pd.read_csv('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allelic_imbalance/quasar/output/all_inference.txt', sep='\t', header=None)
all_inf.sort_values(by=5, inplace=True)
all_inf.drop_duplicates(subset=0, inplace=True)
all_inf = all_inf.loc[all_inf[2].apply(lambda x : x.isdigit())]
all_inf[5] = all_inf[5].astype('float')
sig_snps = all_inf.loc[all_inf[5] < 0.01]
sig_snps.columns = ['rsid', 'chr', 'pos', 'betas', 'se', 'pval']
sig_snps.to_csv('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/allelic_imbalance/quasar/output/top_snps.txt', index=False, sep='\t')
sig_snps
# Out:
#              rsid    chr        pos               betas                 se  \
# 301     rs1237999  chr11   86103987     1.9717165143202  0.514791348973924
# 4819    rs2736990   chr4   89757389     2.0141062365355  0.601414503093494
# 4521    rs1380294   chr4   18022497     1.7789800728783  0.537075398146771
# 6090  rs113075206   chr4     973550    2.03463315735145  0.628964823229829
