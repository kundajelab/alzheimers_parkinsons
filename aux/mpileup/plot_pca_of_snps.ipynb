# %%
rm(list=ls())

# %%
library(ggplot2)
library(data.table)

# %%
eigenval=read.table("/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/mpileup/individual_bams/pca/adpd.1kg.merged.common.pca.eigenval",header=FALSE,sep='\t')

# %%
eigenval$V1=eigenval$V1/sum(eigenval$V1)
eigenval$V2=seq(1,5)

# %%
ggplot(data=eigenval,aes(x=eigenval$V2,
                        y=eigenval$V1))+
geom_bar(stat='identity')+
xlab("PC")+
ylab("Percent Variance Explained")+
theme_bw(20)
# Out:
# plot without title

# %%
#just ADPD
#data=read.table("/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/mpileup/individual_bams/pca/adpd.merged.pca.formatted.csv",header=TRUE,sep='\t')

#ADPD & Phase3 of 1000 Genomes
data=read.table("/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/mpileup/individual_bams/pca/adpd.1kg.merged.common.pca.eigenvec.with.ancestry",header=TRUE,sep='\t')

# %%
head(data)
# Out:
#   FID IID               Disease BrainRegion PC1        PC2        PC3
# 1 AD  ADAD_CAUD_00_0281 ADAD    CAUD        -0.0480834 0.00998564 -0.00417102
# 2 AD  ADAD_CAUD_00_0387 ADAD    CAUD        -0.0475192 0.00845136 -0.00734924
# 3 AD  ADAD_CAUD_01_0164 ADAD    CAUD        -0.0486162 0.00750399 -0.00510131
# 4 AD  ADAD_CAUD_01_1400 ADAD    CAUD        -0.0488489 0.00873177 -0.00905803
# 5 AD  ADAD_CAUD_06_0194 ADAD    CAUD        -0.0491169 0.00961734 -0.00175964
# 6 AD  ADAD_CAUD_06_1486 ADAD    CAUD        -0.0484998 0.00849777 -0.00157290
#   PC4          PC5          Ancestry GeoRegion
# 1  1.22377e-02  0.007473630 ADPD     ADPD
# 2  3.97146e-05  0.000389326 ADPD     ADPD
# 3 -6.42598e-04  0.003359840 ADPD     ADPD
# 4  5.48650e-03  0.000116106 ADPD     ADPD
# 5 -3.24042e-03 -0.002368730 ADPD     ADPD
# 6  8.58487e-03 -0.008841930 ADPD     ADPD

# %%
options(repr.plot.width = 8, repr.plot.height = 6)

ggplot(data=data,
      aes(x=data$PC1,
          y=data$PC2,
          color=data$FID))+
geom_point()+
scale_color_manual(name="Cohort",values=c('#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628','#f781bf','#999999'))+
xlab("PC1")+
ylab("PC2")+
theme_bw(20)
# Out:
# plot without title

# %%
ggplot(data=data,
      aes(x=data$PC1,
          y=data$PC2,
          color=data$GeoRegion))+
geom_point(alpha=0.5)+
xlab("PC1")+
ylab("PC3")
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

ggplot(data=data,
      aes(x=data$PC2,
          y=data$PC3,
          color=data$GeoRegion))+
geom_point(alpha=0.5)+
scale_color_manual(name="Geographic Region",values=c('#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#a65628','#f781bf','#999999'))+
xlab("PC2")+
ylab("PC3")+
theme_bw(20)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

ggplot(data=data,
      aes(x=data$PC2,
          y=data$PC4,
          color=data$GeoRegion))+
geom_point(alpha=0.5)+
scale_color_manual(name="Geographic Region",values=c('#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#a65628','#f781bf','#999999'))+
xlab("PC2")+
ylab("PC4")+
theme_bw(20)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

ggplot(data=data,
      aes(x=data$PC3,
          y=data$PC4,
          color=data$GeoRegion))+
geom_point(alpha=0.5)+
scale_color_manual(name="Geographic Region",values=c('#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#a65628','#f781bf','#999999'))+
xlab("PC3")+
ylab("PC4")+
theme_bw(20)
# Out:
# plot without title

# %%
min_pc2=min(data$PC2)
max_pc2=max(data$PC2)
min_pc3=min(data$PC3)
max_pc3=max(data$PC3)

# %%
subset=data[data$GeoRegion=="ADPD",]
head(subset)
# Out:
#   FID IID               Disease BrainRegion PC1        PC2        PC3
# 1 AD  ADAD_CAUD_00_0281 ADAD    CAUD        -0.0480834 0.00998564 -0.00417102
# 2 AD  ADAD_CAUD_00_0387 ADAD    CAUD        -0.0475192 0.00845136 -0.00734924
# 3 AD  ADAD_CAUD_01_0164 ADAD    CAUD        -0.0486162 0.00750399 -0.00510131
# 4 AD  ADAD_CAUD_01_1400 ADAD    CAUD        -0.0488489 0.00873177 -0.00905803
# 5 AD  ADAD_CAUD_06_0194 ADAD    CAUD        -0.0491169 0.00961734 -0.00175964
# 6 AD  ADAD_CAUD_06_1486 ADAD    CAUD        -0.0484998 0.00849777 -0.00157290
#   PC4          PC5          Ancestry GeoRegion
# 1  1.22377e-02  0.007473630 ADPD     ADPD
# 2  3.97146e-05  0.000389326 ADPD     ADPD
# 3 -6.42598e-04  0.003359840 ADPD     ADPD
# 4  5.48650e-03  0.000116106 ADPD     ADPD
# 5 -3.24042e-03 -0.002368730 ADPD     ADPD
# 6  8.58487e-03 -0.008841930 ADPD     ADPD

# %%
##order by PC1 to resolve ancestry 
pc2_adpd=subset[order(subset$PC2),]

# %%
head(pc2_adpd,n=15)
# Out:
#     FID IID               Disease BrainRegion PC1        PC2
# 59  AD  CTRH_HIPP_07_1144 CTRH    HIPP        -0.0395497 -0.01818800
# 48  AD  CTRH_CAUD_07_1144 CTRH    CAUD        -0.0394410 -0.01793620
# 81  AD  CTRH_SMTG_07_1144 CTRH    SMTG        -0.0370147 -0.01764310
# 39  AD  ADAD_SMTG_23710xx ADAD    SMTG        -0.0414147 -0.01758840
# 70  AD  CTRH_PARL_07_1144 CTRH    PARL        -0.0364331 -0.01724460
# 29  AD  ADAD_PARL_WYYIWGx ADAD    PARL        -0.0392291 -0.01661860
# 20  AD  ADAD_PARL_02_0621 ADAD    PARL        -0.0409400 -0.01648500
# 33  AD  ADAD_SMTG_02_0621 ADAD    SMTG        -0.0407972 -0.01644490
# 46  AD  ADAD_SMTG_WYYIWGx ADAD    SMTG        -0.0399999 -0.01643720
# 16  AD  ADAD_CAUD_WYYIWGx ADAD    CAUD        -0.0379376 -0.01527280
# 348 PD  LOPD_MDFG_10_83   LOPD    MDFG        -0.0455010  0.00521435
# 363 PD  LOPD_MDTG_10_83   LOPD    MDTG        -0.0467805  0.00531858
# 14  AD  ADAD_CAUD_DCQGVNx ADAD    CAUD        -0.0491375  0.00571430
# 327 PD  LOPD_CAUD_10_83   LOPD    CAUD        -0.0484161  0.00584658
# 271 PD  GBA1_MDFG_03_43   GBA1    MDFG        -0.0459851  0.00589503
#     PC3         PC4          PC5          Ancestry GeoRegion
# 59  -0.09886080 -0.010528100  0.012219500 ADPD     ADPD
# 48  -0.09983970 -0.010193800  0.016946100 ADPD     ADPD
# 81  -0.09419300 -0.008151270  0.013857100 ADPD     ADPD
# 39  -0.10461600 -0.003044520  0.016195900 ADPD     ADPD
# 70  -0.09321060 -0.007596190  0.012703200 ADPD     ADPD
# 29  -0.10243500 -0.011928500  0.001701850 ADPD     ADPD
# 20  -0.09953840 -0.014040100  0.009340260 ADPD     ADPD
# 33  -0.09927810 -0.012042100  0.009842790 ADPD     ADPD
# 46  -0.10303900 -0.012368600  0.000199412 ADPD     ADPD
# 16  -0.09906520 -0.010793100  0.002035330 ADPD     ADPD
# 348 -0.00227036 -0.001537320 -0.017476800 ADPD     ADPD
# 363 -0.00149606 -0.000551216 -0.015836300 ADPD     ADPD
# 14  -0.00839712 -0.007323790  0.007261120 ADPD     ADPD
# 327 -0.00373203 -0.003313900 -0.017607300 ADPD     ADPD
# 271 -0.00534032 -0.002767400 -0.004388390 ADPD     ADPD

# %%
tail(pc2_adpd,n=12)
# Out:
#     FID IID               Disease BrainRegion PC1        PC2       PC3
# 269 PD  GBA1_MDFG_00_27   GBA1    MDFG        -0.0460815 0.0140454 -0.01327010
# 398 PD  LRRK_CAUD_10_37   LRRK    CAUD        -0.0470205 0.0140989 -0.00849743
# 409 PD  LRRK_PTMN_10_37   LRRK    PTMN        -0.0478929 0.0141417 -0.01031420
# 412 PD  LRRK_SUNI_10_37   LRRK    SUNI        -0.0478474 0.0142068 -0.00949570
# 106 AD  CTRL_HIPP_14_1018 CTRL    HIPP        -0.0344775 0.0617803 -0.05905480
# 121 AD  CTRL_SMTG_14_1018 CTRL    SMTG        -0.0327688 0.0619724 -0.05688630
# 99  AD  CTRL_CAUD_14_1018 CTRL    CAUD        -0.0353725 0.0631072 -0.05909310
# 113 AD  CTRL_PARL_14_1018 CTRL    PARL        -0.0340860 0.0640712 -0.05959570
# 67  AD  CTRH_HIPP_15_1023 CTRH    HIPP        -0.0322134 0.0717676 -0.06743970
# 89  AD  CTRH_SMTG_15_1023 CTRH    SMTG        -0.0327972 0.0731335 -0.06961040
# 78  AD  CTRH_PARL_15_1023 CTRH    PARL        -0.0330149 0.0734962 -0.07022890
# 56  AD  CTRH_CAUD_15_1023 CTRH    CAUD        -0.0317352 0.0735063 -0.06892190
#     PC4          PC5         Ancestry GeoRegion
# 269 -0.003248530  0.00737339 ADPD     ADPD
# 398 -0.000598058 -0.00302735 ADPD     ADPD
# 409 -0.000610499 -0.00347377 ADPD     ADPD
# 412 -0.001625230 -0.00375529 ADPD     ADPD
# 106 -0.007425770  0.02049590 ADPD     ADPD
# 121 -0.007509670  0.02273890 ADPD     ADPD
# 99  -0.007322270  0.02185930 ADPD     ADPD
# 113 -0.006347320  0.02327000 ADPD     ADPD
# 67  -0.009886090  0.03257060 ADPD     ADPD
# 89  -0.011823900  0.02820120 ADPD     ADPD
# 78  -0.013234700  0.03304150 ADPD     ADPD
# 56  -0.009346640  0.03224190 ADPD     ADPD

# %%
pc3_adpd=subset[order(subset$PC3),]

# %%
head(pc3_adpd,n=30)
# Out:
#     FID IID               Disease BrainRegion PC1        PC2         PC3
# 39  AD  ADAD_SMTG_23710xx ADAD    SMTG        -0.0414147 -0.01758840 -0.1046160
# 46  AD  ADAD_SMTG_WYYIWGx ADAD    SMTG        -0.0399999 -0.01643720 -0.1030390
# 29  AD  ADAD_PARL_WYYIWGx ADAD    PARL        -0.0392291 -0.01661860 -0.1024350
# 48  AD  CTRH_CAUD_07_1144 CTRH    CAUD        -0.0394410 -0.01793620 -0.0998397
# 20  AD  ADAD_PARL_02_0621 ADAD    PARL        -0.0409400 -0.01648500 -0.0995384
# 33  AD  ADAD_SMTG_02_0621 ADAD    SMTG        -0.0407972 -0.01644490 -0.0992781
# 16  AD  ADAD_CAUD_WYYIWGx ADAD    CAUD        -0.0379376 -0.01527280 -0.0990652
# 59  AD  CTRH_HIPP_07_1144 CTRH    HIPP        -0.0395497 -0.01818800 -0.0988608
# 81  AD  CTRH_SMTG_07_1144 CTRH    SMTG        -0.0370147 -0.01764310 -0.0941930
# 70  AD  CTRH_PARL_07_1144 CTRH    PARL        -0.0364331 -0.01724460 -0.0932106
# 78  AD  CTRH_PARL_15_1023 CTRH    PARL        -0.0330149  0.07349620 -0.0702289
# 89  AD  CTRH_SMTG_15_1023 CTRH    SMTG        -0.0327972  0.07313350 -0.0696104
# 56  AD  CTRH_CAUD_15_1023 CTRH    CAUD        -0.0317352  0.07350630 -0.0689219
# 67  AD  CTRH_HIPP_15_1023 CTRH    HIPP        -0.0322134  0.07176760 -0.0674397
# 113 AD  CTRL_PARL_14_1018 CTRL    PARL        -0.0340860  0.06407120 -0.0595957
# 99  AD  CTRL_CAUD_14_1018 CTRL    CAUD        -0.0353725  0.06310720 -0.0590931
# 106 AD  CTRL_HIPP_14_1018 CTRL    HIPP        -0.0344775  0.06178030 -0.0590548
# 121 AD  CTRL_SMTG_14_1018 CTRL    SMTG        -0.0327688  0.06197240 -0.0568863
# 208 PD  CTRL_MDFG_09_50   CTRL    MDFG        -0.0476119  0.01007820 -0.0312474
# 246 PD  CTRL_SUNI_09_50   CTRL    SUNI        -0.0470694  0.00996344 -0.0295718
# 232 PD  CTRL_PTMN_09_50   CTRL    PTMN        -0.0456673  0.00977951 -0.0284787
# 220 PD  CTRL_MDTG_09_50   CTRL    MDTG        -0.0459677  0.00948421 -0.0281555
# 395 PD  LOPD_SUNI_13_44   LOPD    SUNI        -0.0465753  0.00754452 -0.0176248
# 312 PD  GBA1_SUNI_00_27   GBA1    SUNI        -0.0512368  0.01393800 -0.0151633
# 155 AD  LOAD_PARL_07_0997 LOAD    PARL        -0.0477807  0.00658890 -0.0142618
# 140 AD  LOAD_HIPP_07_0997 LOAD    HIPP        -0.0477825  0.00616996 -0.0139243
# 250 PD  GBA1_CAUD_00_27   GBA1    CAUD        -0.0463257  0.01367540 -0.0138338
# 410 PD  LRRK_PTMN_13_60   LRRK    PTMN        -0.0468327  0.01163230 -0.0134299
# 269 PD  GBA1_MDFG_00_27   GBA1    MDFG        -0.0460815  0.01404540 -0.0132701
# 8   AD  ADAD_CAUD_12829xx ADAD    CAUD        -0.0486077  0.00797428 -0.0124114
#     PC4          PC5          Ancestry GeoRegion
# 39  -3.04452e-03  0.016195900 ADPD     ADPD
# 46  -1.23686e-02  0.000199412 ADPD     ADPD
# 29  -1.19285e-02  0.001701850 ADPD     ADPD
# 48  -1.01938e-02  0.016946100 ADPD     ADPD
# 20  -1.40401e-02  0.009340260 ADPD     ADPD
# 33  -1.20421e-02  0.009842790 ADPD     ADPD
# 16  -1.07931e-02  0.002035330 ADPD     ADPD
# 59  -1.05281e-02  0.012219500 ADPD     ADPD
# 81  -8.15127e-03  0.013857100 ADPD     ADPD
# 70  -7.59619e-03  0.012703200 ADPD     ADPD
# 78  -1.32347e-02  0.033041500 ADPD     ADPD
# 89  -1.18239e-02  0.028201200 ADPD     ADPD
# 56  -9.34664e-03  0.032241900 ADPD     ADPD
# 67  -9.88609e-03  0.032570600 ADPD     ADPD
# 113 -6.34732e-03  0.023270000 ADPD     ADPD
# 99  -7.32227e-03  0.021859300 ADPD     ADPD
# 106 -7.42577e-03  0.020495900 ADPD     ADPD
# 121 -7.50967e-03  0.022738900 ADPD     ADPD
# 208  2.28255e-02  0.075013400 ADPD     ADPD
# 246  2.13259e-02  0.074779800 ADPD     ADPD
# 232  2.31156e-02  0.073682300 ADPD     ADPD
# 220  2.18411e-02  0.074641400 ADPD     ADPD
# 395  2.62958e-05  0.003133600 ADPD     ADPD
# 312 -5.12081e-03  0.011851000 ADPD     ADPD
# 155  2.70789e-03  0.034301000 ADPD     ADPD
# 140  3.72276e-03  0.035894000 ADPD     ADPD
# 250 -2.53289e-03  0.010650600 ADPD     ADPD
# 410 -5.93481e-03 -0.003502830 ADPD     ADPD
# 269 -3.24853e-03  0.007373390 ADPD     ADPD
# 8   -3.75527e-03  0.007287130 ADPD     ADPD

# %%
tail(pc3_adpd)
# Out:
#     FID IID               Disease BrainRegion PC1        PC2        PC3
# 66  AD  CTRH_HIPP_14_1383 CTRH    HIPP        -0.0450068 0.00761213 0.00101610
# 149 AD  LOAD_HIPP_12_1181 LOAD    HIPP        -0.0472849 0.01271380 0.00105316
# 375 PD  LOPD_PTMN_11_70   LOPD    PTMN        -0.0480267 0.00970944 0.00132917
# 142 AD  LOAD_HIPP_09_1166 LOAD    HIPP        -0.0484422 0.01141620 0.00187630
# 349 PD  LOPD_MDFG_11_70   LOPD    MDFG        -0.0464399 0.00976258 0.00191828
# 125 AD  LOAD_CAUD_09_1166 LOAD    CAUD        -0.0486608 0.01124900 0.00244325
#     PC4         PC5          Ancestry GeoRegion
# 66  -0.00289202 -0.000667893 ADPD     ADPD
# 149 -0.00757588  0.001571760 ADPD     ADPD
# 375  0.00378503 -0.018631400 ADPD     ADPD
# 142 -0.00344732  0.000969455 ADPD     ADPD
# 349  0.00434273 -0.021878300 ADPD     ADPD
# 125 -0.00556332  0.002030220 ADPD     ADPD

# %%
options(repr.plot.width = 15, repr.plot.height = 6)

ggplot(data=subset,
      aes(x=subset$PC2,
          y=subset$PC3,
          alpha=subset$Ancestry))+
geom_point()+
scale_alpha_manual(name="Indivdiual with reported 'mixed' ancestry vs ADPD",values=c(0.01,1))+
xlab("PC2")+
ylab("PC3")+
xlim(c(min_pc2,max_pc2))+
ylim(c(min_pc3,max_pc3))+
theme_bw(20)
# Out:
# plot without title

# %%
options(repr.plot.width = 6, repr.plot.height = 6)

ggplot(data=subset,
      aes(x=subset$PC1,
          y=subset$PC2,
         color=subset$BrainRegion))+
geom_point()+
scale_color_manual(values=c('#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628','#f781bf','#999999'))+
xlab("PC1")+
ylab("PC2")
# Out:
# plot without title

# %%
ggplot(data=subset,
      aes(x=subset$PC4,
          y=subset$PC5,
         color=subset$Disease))+
geom_point()+
scale_color_manual(values=c('#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628','#f781bf','#999999'))+
xlab("PC4")+
ylab("PC5")
# Out:
# plot without title
