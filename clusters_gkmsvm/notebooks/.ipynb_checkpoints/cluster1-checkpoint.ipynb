# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.insert(0, "/users/soumyak/alzheimers_parkinsons/clusters_gkmsvm")
from viz_preprocess import *
from viz_sequence import *
import pysam
import pickle
import random
import modisco
import warnings
import plotnine
import pybedtools
import numpy as np
import tabix as tb
import pandas as pd
from plotnine import *
from pandas import Series
from kerasAC.splits import *
from matplotlib import pyplot as plt
from deeplift.dinuc_shuffle import dinuc_shuffle

from dragonn.interpret import * 
from dragonn.vis import *
from dragonn.utils import *

from scipy import stats

np.random.seed(1234)
plt.style.use('default')

# %% [markdown]
# ## Select Cluster and GWAS

# %%
cluster = '1'

snps = pd.read_csv('/mnt/lab_data3/soumyak/adpd/snp_lists/Cluster'+cluster+'.overlap.expanded.snps.hg38.bed', sep='\t')

# %% [markdown]
# ## Prepare Major Alleles

# %%
effect_fasta = '/mnt/lab_data3/soumyak/adpd/fasta_inputs/Cluster'+cluster+'.effect.fasta'
effect_seqs = [x.rstrip() for (i,x) in enumerate(open(effect_fasta)) if i%2==1]
effect_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in effect_seqs]

print("Num onehot sequences:", len(effect_onehot))

merged_effect_scores = np.zeros(shape=(len(effect_onehot), 1000, 4))

for fold in range(7,8):
    effect_file = '/oak/stanford/groups/akundaje/soumyak/explain_scores/Cluster'+cluster+'/fold'+str(fold)+'.effect.scores.txt'
    effect_scores = get_hyp_scores(effect_file, effect_seqs)
    effect_scores = np.array(effect_scores)
    merged_effect_scores = merged_effect_scores + effect_scores
    print(merged_effect_scores.shape)
    
merged_effect_scores = merged_effect_scores / (fold + 1)
# Out:
# Num onehot sequences: 642
# (642, 1000, 4)

# %% [markdown]
# ## Prepare Minor Alleles

# %%
noneffect_fasta = '/mnt/lab_data3/soumyak/adpd/fasta_inputs/Cluster'+cluster+'.noneffect.fasta'
noneffect_seqs = [x.rstrip() for (i,x) in enumerate(open(noneffect_fasta)) if i%2==1]
noneffect_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in noneffect_seqs]

print("Num onehot sequences:", len(noneffect_onehot))

merged_noneffect_scores = np.zeros(shape=(len(noneffect_onehot), 1000, 4))

for fold in range(7,8):
    noneffect_file = '/oak/stanford/groups/akundaje/soumyak/explain_scores/Cluster'+cluster+'/fold'+str(fold)+'.noneffect.scores.txt'
    noneffect_scores = get_hyp_scores(noneffect_file, noneffect_seqs)
    noneffect_scores = np.array(noneffect_scores)
    merged_noneffect_scores = merged_noneffect_scores + noneffect_scores
    print(merged_noneffect_scores.shape)
    
merged_noneffect_scores = merged_noneffect_scores / (fold + 1)
# Out:
# Num onehot sequences: 642
# (642, 1000, 4)

# %% [markdown]
# ## Prepare DataFrame

# %%
effect_score = []
noneffect_score = []
effect_center = []
noneffect_center = []
effect_ratio = []
noneffect_ratio = []
allele_ratio = []
effect_rank = []
noneffect_rank = []
for index,row in snps.iterrows():
    effect_score.append(np.sum(np.array([np.sum(j) for j in merged_effect_scores[index][400:600]])))
    noneffect_score.append(np.sum(np.array([np.sum(j) for j in merged_noneffect_scores[index][400:600]])))
    effect_center.append(np.sum(np.array([max(0, np.sum(j)) for j in merged_effect_scores[index][475:525]])))
    noneffect_center.append(np.sum(np.array([max(0, np.sum(j)) for j in merged_noneffect_scores[index][475:525]])))
    effect_ratio.append(np.sum(np.array([max(0, np.sum(j)) for j in merged_effect_scores[index][490:510]])) / np.sum(np.array([max(0, np.sum(j)) for j in merged_effect_scores[index][400:600]])))
    noneffect_ratio.append(np.sum(np.array([max(0, np.sum(j)) for j in merged_noneffect_scores[index][490:510]])) / np.sum(np.array([max(0, np.sum(j)) for j in merged_noneffect_scores[index][400:600]])))
    allele_ratio.append(effect_center[-1] / (noneffect_center[-1] + 0.00001))
    effect_rank.append((effect_center[-1] / (noneffect_center[-1] + 0.00001)) * effect_ratio[-1])
    noneffect_rank.append((noneffect_center[-1] / (effect_center[-1] + 0.00001)) * noneffect_ratio[-1])
snps['effect_score'] = effect_score
snps['noneffect_score'] = noneffect_score
snps['effect_center'] = effect_center
snps['noneffect_center'] = noneffect_center
snps['effect_ratio'] = effect_ratio
snps['noneffect_ratio'] = noneffect_ratio
snps['allele_ratio'] = allele_ratio
snps['effect_rank'] = effect_rank
snps['noneffect_rank'] = noneffect_rank

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
neg_snps = snps.loc[snps['allele_ratio'] >= 1]
neg_snps.sort_values(by=['effect_rank'], ascending=False, inplace=True)
display(neg_snps)
# Out:
#        chr      start        end         rsid effect noneffect ref    alt  \
# 133  chr17    4899021    4899022   rs55681486      T         C   T      C
# 222  chr17   45852666   45852667   rs62054825      G         A   G      A
# 41   chr11   60251676   60251677     rs636317      C         T   C      T
# 430   chr2   95324017   95324018    rs3772034      G         A   G      A
# 240  chr17   45896863   45896864   rs62056782      T         C   C      T
# 47   chr11   65834088   65834089   rs17854357      C         G   G    C,T
# 630   chr8   27369272   27369273     rs755951      C         A   A    C,T
# 575   chr4   89836583   89836584    rs2619361      A         C   C      A
# 63   chr11  121590239  121590240   rs77819448      G         A   A      G
# 597   chr5  134594837  134594838   rs17167632      G         A   G      A
# 405  chr19   45001090   45001091   rs35577563      G         C   C      G
# 318  chr17   46213482   46213483   rs76475191      T         A   T      A
# 539   chr4   89723193   89723194   rs79596632      G         A   G      A
# 330  chr17   61862882   61862883   rs16945692      G         A   A      G
# 12    chr1  232521986  232521987   rs34331262      G         A   A    C,G
# 587   chr4   90290372   90290373   rs75541595      G         A   G      A
# 621   chr8   11853639   11853640    rs1293295      C         A   C    A,T
# 425   chr2   95301997   95301998    rs9989786      G         A   A      G
# 270  chr17   45959712   45959713  rs113793114      G         A   G      A
# 72   chr12   40499862   40499863  rs117937897      G         A   G    A,C
# 294  chr17   46038519   46038520   rs12150090      T         C   C    G,T
# 264  chr17   45958920   45958921   rs62063275      G         A   A      G
# 4     chr1  171741264  171741265    rs2298914      T         C   C      T
# 324  chr17   46758935   46758936    rs9912530      T         C   T      C
# 366  chr19   44723890   44723891  rs150820726      T         A   A      T
# 539     G      A         -             1.10275e-12           23andme_PD_hg38
# 330     A      G         +   9.347629999999999e-05             Nalls_23andMe
# 12      A    C,G         +              0.00109494  Chang_23andMe_Parkinsons
# 587     G      A         -             5.29959e-09           23andme_PD_hg38
# 621     C    A,T         +             1.89005e-05  Chang_23andMe_Parkinsons
# 425     G      A         +               0.0115161             Nalls_23andMe
# 270     G      A         +             2.58186e-22           23andme_PD_hg38
# 72      G    A,C         -             6.81278e-14             Nalls_23andMe
# 294     C    G,T         -             2.50835e-22           23andme_PD_hg38
# 264     A      G         -               2.645e-22           23andme_PD_hg38
# 4       C      T         -             0.062159748             Nalls_23andMe
# 324     C      T         -             1.46656e-12           23andme_PD_hg38
# 366     A      T         +       1.01590829918e-11    Alzheimers_Jansen_2018
# 242     G      T         -             3.93872e-22           23andme_PD_hg38
# 91      C    A,T         -        0.00440314896679    Alzheimers_Jansen_2018
# 352     C    A,G         -      0.6594072461770001    Alzheimers_Jansen_2018
# 565     G      A         -             4.78817e-09           23andme_PD_hg38
# 302     G      A         +  2.5841000000000006e-22           23andme_PD_hg38
# ..    ...    ...       ...                     ...                       ...
# 92      C      G         -       6.66345206061e-06    Alzheimers_Jansen_2018
# 93      C      G         .                       .  Parkinsons_Pankratz_2012
# 502     A      G         .                       .  Parkinsons_Pankratz_2012
# 268     C      T         -  1.2268699999999998e-21           23andme_PD_hg38
# 246     C      T         -  3.9400699999999993e-22           23andme_PD_hg38
# 208     G      T         -  2.9341200000000006e-22           23andme_PD_hg38
# 11      T      C         -              0.00111463  Chang_23andMe_Parkinsons
# 373     C  A,G,T         -  1.4528398806499999e-21    Alzheimers_Jansen_2018
# 623     T      C         -    0.050811199999999994  Chang_23andMe_Parkinsons
# 278     C      G         -  2.1840299999999997e-22           23andme_PD_hg38
# 237     A      G         -             2.87736e-22           23andme_PD_hg38
# 382     G    A,C         +  5.794108067979998e-167    Alzheimers_Jansen_2018
# 329     T      C         +   4.949624366109999e-07    Alzheimers_Jansen_2018
# 103     A      G         +               0.0054635  Chang_23andMe_Parkinsons
# 50      G      A         +               0.0167551  Chang_23andMe_Parkinsons
# 284     C      T         -  2.0934000000000002e-22           23andme_PD_hg38
# 371     C      T         -               2.892e-05    Alzheimers_Kunkle_2019
# 552     G      A         -             3.74307e-12           23andme_PD_hg38
# 26      A      G         +               1.472e-10    Alzheimers_Kunkle_2019
# 177     G      T         -  2.0925400000000002e-22           23andme_PD_hg38
# 30      G      A         +       1.55729068059e-06    Alzheimers_Jansen_2018
# 139     A      T         -               0.0005654    Alzheimers_Kunkle_2019
# 44      G    GTA         +   5.421000000000001e-16    Alzheimers_Kunkle_2019
# 281     G      A         +             2.18352e-22           23andme_PD_hg38
# 635     C      T         +               0.0795385             Nalls_23andMe
# 339     G      A         +               2.427e-05    Alzheimers_Kunkle_2019
# 427     G    T,A         -              0.00717146             Nalls_23andMe
# 74      T      G         -              2.6331e-12           23andme_PD_hg38
# 130     C      T         +  0.00026389999999999996    Alzheimers_Kunkle_2019
# 48      G    A,C         -       4.65537046358e-06    Alzheimers_Jansen_2018
    print("Effect Allele: ", neg_snps.at[idx, 'effect'], ' Effect Sequence: ', effect_seqs[idx][490:510])
    ylim = plot_weights(merged_effect_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", neg_snps.at[idx, 'noneffect_score'], " RSID: ", neg_snps.at[idx, 'rsid'])
    print("Noneffect Allele: ", neg_snps.at[idx, 'noneffect'], ' Noneffect Sequence: ', noneffect_seqs[idx][490:510])
    a = plot_weights(merged_noneffect_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Allele Ratio: ", neg_snps.at[idx, 'allele_ratio'], " RSID: ", neg_snps.at[idx, 'rsid'])
    print("Noneffect - Effect: ", neg_snps.at[idx, 'noneffect'] + ' - ' + neg_snps.at[idx, 'effect'])
    a = plot_weights(merged_noneffect_scores[idx] - merged_effect_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  133  Importance:  0.2871860181  RSID:  rs55681486   chr17 : 4899021 - 4899022
# Effect Allele:  T  Effect Sequence:  CTCCTGATCTCTCGTGCTCT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-9c6dff036a22> in <module>
#       4           ' ', neg_snps.at[idx, 'chr'], ':', neg_snps.at[idx, 'start'], '-', neg_snps.at[idx, 'end'])
#       5     print("Effect Allele: ", neg_snps.at[idx, 'effect'], ' Effect Sequence: ', effect_seqs[idx][490:510])
# ----> 6     ylim = plot_weights(merged_effect_scores[idx], subticks_frequency=10, xlim=(400,600))
#       7     print("Index: ", idx, " Importance: ", neg_snps.at[idx, 'noneffect_score'], " RSID: ", neg_snps.at[idx, 'rsid'])
#       8     print("Noneffect Allele: ", neg_snps.at[idx, 'noneffect'], ' Noneffect Sequence: ', noneffect_seqs[idx][490:510])
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_weights(array, figsize, height_padding_factor, length_padding, subticks_frequency, colors, plot_funcs, highlight, ylim, xlim, ylabel)
#     160         ylim=ylim,
#     161         xlim=xlim,
# --> 162         ylabel=ylabel)
#     163     plt.show()
#     164     return ylim
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_weights_given_ax(ax, array, height_padding_factor, length_padding, subticks_frequency, highlight, colors, plot_funcs, ylim, xlim, ylabel)
#     102                 height_so_far = negative_height_so_far
#     103                 negative_height_so_far += letter[1]
# --> 104             plot_func(ax=ax, base=height_so_far, left_edge=i, height=letter[1], color=color)
#     105         max_pos_height = max(max_pos_height, positive_height_so_far)
#     106         min_neg_height = min(min_neg_height, negative_height_so_far)
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_g(ax, base, left_edge, height, color)
#      51                                             facecolor=color, edgecolor=color))
#      52     ax.add_patch(matplotlib.patches.Ellipse(xy=[left_edge+0.65, base+0.5*height], width=0.7*1.3, height=0.7*height,
# ---> 53                                             facecolor='white', edgecolor='white'))
#      54     ax.add_patch(matplotlib.patches.Rectangle(xy=[left_edge+1, base], width=1.0, height=height,
#      55                                             facecolor='white', edgecolor='white', fill=True))
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2033         if p.get_clip_path() is None:
#    2034             p.set_clip_path(self.patch)
# -> 2035         self._update_patch_limits(p)
#    2036         self.patches.append(p)
#    2037         p._remove_method = lambda h: self.patches.remove(h)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2062                 contains_branch_seperately(self.transData)
#    2063             self.update_datalim(xys, updatex=updatex,
# -> 2064                                 updatey=updatey)
#    2065
#    2066     def add_table(self, tab):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/axes/_base.py in update_datalim(self, xys, updatex, updatey)
#    2146             return
#    2147         self.dataLim.update_from_data_xy(xys, self.ignore_existing_data_limits,
# -> 2148                                          updatex=updatex, updatey=updatey)
#    2149         self.ignore_existing_data_limits = False
#    2150
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in update_from_data_xy(self, xy, ignore, updatex, updatey)
#     927         path = Path(xy)
#     928         self.update_from_path(path, ignore=ignore,
# --> 929                                     updatex=updatex, updatey=updatey)
#     930
#     931     @BboxBase.x0.setter
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in update_from_path(self, path, ignore, updatex, updatey)
#     892
#     893         points, minpos, changed = update_path_extents(
# --> 894             path, None, self._points, self._minpos, ignore)
#     895
#     896         if changed:
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f1f39ccb1e0> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x7f1f39cc5158> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </users/soumyak/miniconda3/envs/dragonn/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/patches.py in draw(self, renderer)
#     548
#     549         path = self.get_path()
# --> 550         transform = self.get_transform()
#     551         tpath = transform.transform_path_non_affine(path)
#     552         affine = transform.get_affine()
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/patches.py in get_transform(self)
#     197         to the :class:`Patch`.
#     198         """
# --> 199         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     200
#     201     def get_data_transform(self):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     735
#     736     def get_patch_transform(self):
# --> 737         self._update_patch_transform()
#     738         return self._rect_transform
#     739
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/patches.py in _update_patch_transform(self)
#     714         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     715         rot_trans = transforms.Affine2D()
# --> 716         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     717         self._rect_transform = transforms.BboxTransformTo(bbox)
#     718         self._rect_transform += rot_trans
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in rotate_deg_around(self, x, y, degrees)
#    2051         # Cast to float to avoid wraparound issues with uint8's
#    2052         x, y = float(x), float(y)
# -> 2053         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    2054
#    2055     def translate(self, tx, ty):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in rotate_deg(self, degrees)
#    2029         and :meth:`scale`.
#    2030         """
# -> 2031         return self.rotate(np.deg2rad(degrees))
#    2032
#    2033     def rotate_around(self, x, y, theta):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in rotate(self, theta)
#    2017         rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#    2018                               float)
# -> 2019         self._mtx = np.dot(rotate_mtx, self._mtx)
#    2020         self.invalidate()
#    2021         return self
#
# KeyboardInterrupt:

# %%
pd.set_option('display.max_columns', None)
snps.loc[snps['rsid'] == 'rs1237999']
# Out:
#       chr     start       end       rsid effect noneffect ref alt major minor  \
# 59  chr11  86103987  86103988  rs1237999      A         G   G   A     A     G
# 60  chr11  86103987  86103988  rs1237999      G         A   G   A     A     G
#
#    direction                  pvalue             source_gwas  locus_num  \
# 59         +               1.463e-13  Alzheimers_Kunkle_2019         16
# 60         -  7.1431480803899985e-16  Alzheimers_Jansen_2018         16
#
#     ld_tag_chr  ld_tag_pos  r2_with_ld_tag  effect_score  noneffect_score  \
# 59          11    86103988             1.0      0.120909         0.184106
# 60          11    86103988             1.0      0.184106         0.120909
#
#     effect_center  noneffect_center  effect_ratio  noneffect_ratio  \
# 59       0.027234          0.039681      0.009049         0.071369
# 60       0.039681          0.027234      0.071369         0.009049
#
#     allele_ratio  effect_rank  noneffect_rank
# 59      0.686143     0.006209        0.103950
# 60      1.456520     0.103950        0.006209

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
pos_snps = snps.loc[snps['allele_ratio'] < 1]
pos_snps.sort_values(by=['noneffect_rank'], ascending=False, inplace=True)
display(pos_snps)
# Out:
#        chr      start        end         rsid effect noneffect ref    alt  \
# 132  chr17    4899021    4899022   rs55681486      C         T   T      C
# 42   chr11   60251676   60251677     rs636317      T         C   C      T
# 417  chr19   45326123   45326124     rs344792      A         G   G      A
# 629   chr8   27369272   27369273     rs755951      A         C   A    C,T
# 311  chr17   46130945   46130946    rs6503457      T         G   G  A,C,T
# 576   chr4   89836583   89836584    rs2619361      C         A   C      A
# 484   chr3   52232789   52232790  rs140991232      G         C   G      C
# 404  chr19   45001090   45001091   rs35577563      C         G   C      G
# 253  chr17   45910838   45910839    rs2435204      G         A   A      G
# 474   chr3   18240966   18240967   rs35274326      G         C   C      G
# 358  chr19   18462023   18462024    rs8103622      T         C   C      T
# 482   chr3   49007333   49007334    rs6781790      T         C   C      T
# 638   chr9   17579764   17579765   rs12683178      G         C   C      G
# 304  chr17   46130520   46130521   rs10514904      T         C   C      T
# 460   chr2  134762963  134762964   rs13033373      T         C   T      C
# 418  chr19   45326535   45326536     rs344791      C         G   G      C
# 188  chr17   45740531   45740532   rs80157557      G         A   G      A
# 498   chr3  122458998  122458999   rs56118506      T         C   C      T
# 484     G      C         -   0.0009767530000000001  Chang_23andMe_Parkinsons
# 404     C      G         -               4.759e-09    Alzheimers_Kunkle_2019
# 253     A      G         -             8.94571e-22           23andme_PD_hg38
# 474     C      G         +             8.22203e-05  Chang_23andMe_Parkinsons
# 358     C      T         +         0.0730573456127    Alzheimers_Jansen_2018
# 482     T      C         +              0.00234934  Chang_23andMe_Parkinsons
# 638     C      G         -             7.72716e-05  Chang_23andMe_Parkinsons
# 304     C      T         -             2.69308e-22           23andme_PD_hg38
# 460     T      C         +               0.0100347             Nalls_23andMe
# 418     C      G         -       0.000121567109578    Alzheimers_Jansen_2018
# 188     G      A         +  2.9143099999999995e-22           23andme_PD_hg38
# 498     C      T         +             0.000544645             Nalls_23andMe
# 641     A      G         +                0.189133             Nalls_23andMe
# 65      G      A         -             1.46067e-07           23andme_PD_hg38
# 351     C    A,G         -               9.907e-05    Alzheimers_Kunkle_2019
# 239     C    G,T         -             3.93836e-22           23andme_PD_hg38
# 564     G      A         +               1.255e-07  Parkinsons_Pankratz_2012
# 36      A      G         -               1.722e-07   Alzheimers_Lambert_2013
# 174     A      G         +               2.997e-10  Parkinsons_Pankratz_2012
# 602     C      A         -  6.4367099999999996e-06             Nalls_23andMe
# 542     G      A         -  1.0649700000000001e-18           23andme_PD_hg38
# 626     T      C         -    0.031432299999999996  Chang_23andMe_Parkinsons
# 589     T      C         +   0.0011275319999999999             Nalls_23andMe
# 583     G    C,T         .                       .  Parkinsons_Pankratz_2012
# ..    ...    ...       ...                     ...                       ...
# 604     T      C         -   7.439999999999999e-10    Alzheimers_Kunkle_2019
# 535     G    A,T         .                       .  Parkinsons_Pankratz_2012
# 135     T      C         +                1.07e-05   Alzheimers_Lambert_2013
# 262     A    G,T         -             3.22158e-22           23andme_PD_hg38
# 616     C      T         -             0.000112336             Nalls_23andMe
# 325     A      G         +               4.455e-10  Parkinsons_Pankratz_2012
# 538     A      G         +             1.37857e-18           23andme_PD_hg38
# 590     G      A         +              0.00034313             Nalls_23andMe
# 46      T      C         +               1.716e-15    Alzheimers_Kunkle_2019
# 209     A      G         +               5.089e-10  Parkinsons_Pankratz_2012
# 559     A      G         -               1.209e-07  Parkinsons_Pankratz_2012
# 485     G      C         -   0.0009369830000000001  Chang_23andMe_Parkinsons
# 611     C      T         -                0.002566  Parkinsons_Pankratz_2012
# 525     A      G         +             4.53392e-05           23andme_PD_hg38
# 271     G      A         +   9.544230000000001e-23           23andme_PD_hg38
# 451     .      .         .                       .    Alzheimers_Jansen_2018
# 141     G    A,C         +       1.08807281316e-07    Alzheimers_Jansen_2018
# 159     C      T         -             2.88869e-22           23andme_PD_hg38
# 343     A      G         -    0.016890000000000002   Alzheimers_Lambert_2013
# 516     C    A,T         -  4.2495500000000005e-08           23andme_PD_hg38
# 105     C      T         -              0.00020996             Nalls_23andMe
# 478     T      A         +              0.00213122  Chang_23andMe_Parkinsons
# 140     A      T         +               8.296e-05   Alzheimers_Lambert_2013
# 357     C      A         +     0.05460514463169999    Alzheimers_Jansen_2018
# ## Visualize Top Sequences

# %%
for idx in pos_snps.index[:5]:
    #for idx in [60]:
    print("Index: ", idx, " Importance: ", pos_snps.at[idx, 'noneffect_score'], " RSID: ", pos_snps.at[idx, 'rsid'])
    print("Noneffect Allele: ", pos_snps.at[idx, 'noneffect'], ' Noneffect Sequence: ', noneffect_seqs[idx][490:510])
    ylim = plot_weights(merged_noneffect_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", pos_snps.at[idx, 'effect_score'], " RSID: ", pos_snps.at[idx, 'rsid'], 
          ' ', pos_snps.at[idx, 'chr'], ':', pos_snps.at[idx, 'start'], '-', pos_snps.at[idx, 'end'])
    print("Effect Allele: ", pos_snps.at[idx, 'effect'], ' Effect Sequence: ', effect_seqs[idx][490:510])
    a = plot_weights(merged_effect_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Allele Ratio: ", pos_snps.at[idx, 'allele_ratio'], " RSID: ", pos_snps.at[idx, 'rsid'])
    print("Effect - Noneffect: ", pos_snps.at[idx, 'effect'] + ' - ' + pos_snps.at[idx, 'noneffect'])
    a = plot_weights(merged_effect_scores[idx] - merged_noneffect_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  132  Importance:  0.2871860181  RSID:  rs55681486
# Noneffect Allele:  T  Noneffect Sequence:  CTCCTGATCTCTCGTGCTCT
# Index:  132  Importance:  0.0666041830000001  RSID:  rs55681486   chr17 : 4899021 - 4899022
# Effect Allele:  C  Effect Sequence:  CTCCTGATCCCTCGTGCTCT
# Index:  132  Allele Ratio:  0.0  RSID:  rs55681486
# Effect - Noneffect:  C - T
# Index:  42  Importance:  3.7660480835999994  RSID:  rs636317
# Noneffect Allele:  C  Noneffect Sequence:  CTTTGCTGCCATCTGCTGGG
# Index:  42  Importance:  1.7253778934000001  RSID:  rs636317   chr11 : 60251676 - 60251677
# Effect Allele:  T  Effect Sequence:  CTTTGCTGCTATCTGCTGGG
# Index:  42  Allele Ratio:  0.3228671367935101  RSID:  rs636317
# Effect - Noneffect:  T - C
# Index:  417  Importance:  -1.0426801156  RSID:  rs344792
# Noneffect Allele:  G  Noneffect Sequence:  CTAGTCTCAGACTCCTACCT
# Index:  417  Importance:  -1.5372086925000001  RSID:  rs344792   chr19 : 45326123 - 45326124
# Effect Allele:  A  Effect Sequence:  CTAGTCTCAAACTCCTACCT
# Index:  417  Allele Ratio:  0.19824603009536113  RSID:  rs344792
# Effect - Noneffect:  A - G
# Index:  629  Importance:  -0.38897680300000004  RSID:  rs755951
# Noneffect Allele:  C  Noneffect Sequence:  TTCACTGGCCTGTAGGGGGA
# Index:  629  Importance:  -0.9586239360000002  RSID:  rs755951   chr8 : 27369272 - 27369273
# Effect Allele:  A  Effect Sequence:  TTCACTGGCATGTAGGGGGA
# Index:  629  Allele Ratio:  0.4895155578172472  RSID:  rs755951
# Effect - Noneffect:  A - C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-de867aacb1df> in <module>
#      10     print("Index: ", idx, " Allele Ratio: ", pos_snps.at[idx, 'allele_ratio'], " RSID: ", pos_snps.at[idx, 'rsid'])
#      11     print("Effect - Noneffect: ", pos_snps.at[idx, 'effect'] + ' - ' + pos_snps.at[idx, 'noneffect'])
# ---> 12     a = plot_weights(merged_effect_scores[idx] - merged_noneffect_scores[idx], subticks_frequency=10, xlim=(400,600))
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_weights(array, figsize, height_padding_factor, length_padding, subticks_frequency, colors, plot_funcs, highlight, ylim, xlim, ylabel)
#     161         xlim=xlim,
#     162         ylabel=ylabel)
# --> 163     plt.show()
#     164     return ylim
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </users/soumyak/miniconda3/envs/dragonn/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/patches.py in draw(self, renderer)
#     512
#     513         renderer.open_group('patch', self.get_gid())
# --> 514         gc = renderer.new_gc()
#     515
#     516         gc.set_foreground(self._edgecolor, isRGBA=True)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backend_bases.py in new_gc(self)
#     789         Return an instance of a :class:`GraphicsContextBase`
#     790         """
# --> 791         return GraphicsContextBase()
#     792
#     793     def points_to_pixels(self, points):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backend_bases.py in __init__(self)
#     860         self._rgb = (0.0, 0.0, 0.0, 1.0)
#     861         self._hatch = None
# --> 862         self._hatch_color = colors.to_rgba(rcParams['hatch.color'])
#     863         self._hatch_linewidth = rcParams['hatch.linewidth']
#     864         self._url = None
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     158     """
#     159     # Special-case nth color syntax because it should not be cached.
# --> 160     if _is_nth_color(c):
#     161         from matplotlib import rcParams
#     162         prop_cycler = rcParams['axes.prop_cycle']
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/colors.py in _is_nth_color(c)
#     107 def _is_nth_color(c):
#     108     """Return whether *c* can be interpreted as an item in the color cycle."""
# --> 109     return isinstance(c, six.string_types) and re.match(r"\AC[0-9]\Z", c)
#     110
#     111
#
# ~/miniconda3/envs/dragonn/lib/python3.7/re.py in match(pattern, string, flags)
#     171     """Try to apply the pattern at the start of the string, returning
#     172     a Match object, or None if no match was found."""
# --> 173     return _compile(pattern, flags).match(string)
#     174
#     175 def fullmatch(pattern, string, flags=0):
#
# KeyboardInterrupt:
