# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.insert(0, "/users/soumyak/alzheimers_parkinsons/clusters_gkmsvm")
from viz_preprocess import *
from viz_sequence import *
import pysam
import pickle
import random
import modisco
import warnings
import plotnine
import pybedtools
import numpy as np
import tabix as tb
import pandas as pd
from plotnine import *
from pandas import Series
from kerasAC.splits import *
from matplotlib import pyplot as plt
from deeplift.dinuc_shuffle import dinuc_shuffle

from dragonn.interpret import * 
from dragonn.vis import *
from dragonn.utils import *

np.random.seed(1234)
plt.style.use('default')
# Out:
# TF-MoDISco is using the TensorFlow backend.
# Using TensorFlow backend.

# %% [markdown]
# # Fold 0

# %%
cluster = '1'
fold = '0'
peak = 'overlap'
gwas = 'Nalls'

# %% [markdown]
# ## Prepare Reference Alleles

# %%
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 12

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 12

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(10)
# Out:
#     index   chr      start        end        rsid  locus major_allele  \
# 4       4  chr1  171711151  171711152  rs12119232     13            A
# 10     10  chr1  232657732  232657733  rs34331262     19            A
# 3       3  chr1  171710404  171710405   rs2298914     13            C
# 1       1  chr1  155108166  155108167  rs12726330     11            G
# 5       5  chr1  205663477  205663478  rs12118655     15            A
# 7       7  chr1  205719531  205719532    rs823114     15            G
# 11     11  chr1  232657732  232657733  rs34331262     19            A
# 6       6  chr1  205683354  205683355      rs3805     15            T
# 9       9  chr1  232657646  232657647  rs35186494     19            T
# 2       2  chr1  155108166  155108167  rs12726330     11            G
#
#    minor_allele  major_score  minor_score     delta
# 4             C     3.425879     2.820647 -0.605232
# 10            C     1.613750     1.294413 -0.319336
# 3             T     1.663775     1.537268 -0.126506
# 1             A     1.219721     1.122075 -0.097646
# 5             G     0.730022     0.735906  0.005884
# 7             A     2.649053     2.701191  0.052138
# 11            G     1.613750     1.696899  0.083149
# 6             G     1.254125     1.357841  0.103717
# 9             C     2.995115     3.121748  0.126634
# 2             C     1.219721     1.404185  0.184464

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GGGGGAGACAGTTGGTGCGG
# GGGGGAGACA | GTTGGTGCGG
# CCTCTGCCCAGCTCAGGGAA
# CCTCTGCCCA | GCTCAGGGAA
# GCAAAGGCTCTCCTTTTCCC
# GCAAAGGCTC | TCCTTTTCCC
# TCTGGACCAGGGTACTGGGA
# TCTGGACCAG | GGTACTGGGA
# GCAGGGGCTATATGGTCTCC
# GCAGGGGCTA | TATGGTCTCC

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:1]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  4  Importance:  3.425878816  RSID:  rs12119232   chr1 : 171711151 - 171711152  Locus:  13
# Major Allele:  A
# Index:  4  Importance:  2.820646945  RSID:  rs12119232
# Minor Allele:  C
# Index:  4  Delta:  -0.605231871  RSID:  rs12119232
# Minor - Major:  C - A

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(10)
# Out:
#     index   chr      start        end        rsid  locus major_allele  \
# 32     32  chr2   95989271   95989272   rs3755519     52            T
# 33     33  chr2   95989271   95989272   rs3755519     52            T
# 14     14  chr2  135476858  135476859  rs62171396     48            C
# 29     29  chr2   95977590   95977591    rs889853     52            G
# 35     35  chr2   95989765   95989766   rs3772034     52            A
# 19     19  chr2   95742452   95742453   rs3105100     52            C
# 28     28  chr2   95977590   95977591    rs889853     52            G
# 27     27  chr2   95968204   95968205   rs7574862     52            G
# 20     20  chr2   95742677   95742678   rs3105101     52            A
# 12     12  chr2  135475959  135475960  rs62171393     48            C
#
#    minor_allele  major_score  minor_score     delta
# 32            A     1.694925     2.662038  0.967114
# 33            C     1.694925     2.528420  0.833495
# 14            T     0.487326     1.153433  0.666107
# 29            A    -0.628141    -0.061879  0.566262
# 35            G     1.296865     1.846200  0.549334
# 19            A     1.456490     1.914332  0.457842
# 28            T    -0.628141    -0.216798  0.411342
# 27            A     1.716061     2.118486  0.402425
# 20            C     3.870673     4.208459  0.337786
# 12            G     1.618551     1.944404  0.325853

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GGGTGCAGGAGTGCTCTCTG
# GGGTGCAGGA | GTGCTCTCTG
# GGGTGCAGGCGTGCTCTCTG
# GGGTGCAGGC | GTGCTCTCTG
# ACAGGCGGCTCTGGCAGAGC
# ACAGGCGGCT | CTGGCAGAGC
# ATGAGTGAGATCCACATGCA
# ATGAGTGAGA | TCCACATGCA
# AGGCAGAGGGAGCCCGCGGC
# AGGCAGAGGG | AGCCCGCGGC

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))

# %% [markdown]
# # Fold 4

# %%
cluster = '1'
fold = '4'
peak = 'overlap'
gwas = 'Nalls'

# %% [markdown]
# ## Prepare Reference Alleles

# %%
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 27

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 27

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(20)
# Out:
#     index    chr      start        end         rsid  locus major_allele  \
# 24     24   chr5  133930156  133930157  rs113661575     69            G
# 11     11  chr16   31022638   31022639   rs72800847     33            G
# 2       2  chr16   30934074   30934075    rs3813020     33            A
# 26     26   chr5  133936193  133936194  rs142547906     69            G
# 14     14   chr5  102295069  102295070    rs3776870     67            G
# 25     25   chr5  133930527  133930528   rs17167632     69            G
# 17     17   chr5  102456253  102456254      rs26523     67            C
# 18     18   chr5  102456303  102456304      rs26524     67            A
# 0       0  chr16   28937258   28937259    rs4072402     32            C
# 16     16   chr5  102345915  102345916    rs1826673     67            G
# 23     23   chr5  133930156  133930157  rs113661575     69            G
# 12     12  chr16   31044682   31044683   rs58726213     33            A
# 7       7  chr16   30968588   30968589    rs4889599     33            T
# 1       1  chr16   28937258   28937259    rs4072402     32            C
# 6       6  chr16   30968588   30968589    rs4889599     33            T
# 13     13  chr16   31044896   31044897   rs12445650     33            G
# 22     22   chr5  133929997  133929998  rs111722920     69            T
# 19     19   chr5  102560369  102560370     rs246913     67            G
# 4       4  chr16   30953201   30953202    rs1458202     33            A
# 15     15   chr5  102307591  102307592    rs6881225     67            T
#
#    minor_allele  major_score  minor_score     delta
# 24            C     0.900932     0.319944 -0.580988
# 11            A     0.423023    -0.064606 -0.487629
# 2             G     2.861631     2.465412 -0.396220
# 26            A    -0.949166    -1.331612 -0.382446
# 14            A     0.256845    -0.081429 -0.338275
# 25            A     0.002991    -0.253879 -0.256870
# 17            T     0.904661     0.662213 -0.242448
# 18            G     1.161823     0.975996 -0.185827
# 0             T     0.470375     0.366782 -0.103593
# 16            A     1.406975     1.347818 -0.059157
# 23            A     0.900932     0.842463 -0.058469
# 12            G     2.452248     2.488004  0.035757
# 7             G     3.140493     3.185239  0.044746
# 1             A     0.470375     0.522405  0.052030
# 6             C     3.140493     3.201023  0.060530
# 13            A     2.233028     2.310007  0.076979
# 22            G     0.264789     0.380215  0.115426
# 19            C     1.734870     1.872573  0.137703
# 4             G    -0.159508     0.040237  0.199745
# 15            C     4.258793     4.468843  0.210050

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GAAACAGGCTCCTTCTCTTC
# GAAACAGGCT | CCTTCTCTTC
# GGGGCCCCCTGCCGCCCCTC
# GGGGCCCCCT | GCCGCCCCTC
# GGCTAAGGCTGCTGCCTTGA
# GGCTAAGGCT | GCTGCCTTGA
# CTGGGCTGGCGGCGGCCCAC
# CTGGGCTGGC | GGCGGCCCAC
# ACTGGCCAGGCTTCACGGCT
# ACTGGCCAGG | CTTCACGGCT

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[4:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  4  Importance:  1.0654928517999998  RSID:  rs11780207   chr8 : 22480518 - 22480519  Locus:  82
# Major Allele:  G
# Index:  4  Importance:  0.9110390592  RSID:  rs11780207
# Minor Allele:  A
# Index:  4  Delta:  -0.1544537925999998  RSID:  rs11780207
# Minor - Major:  A - G

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(20)
# Out:
#     index   chr      start        end        rsid  locus major_allele  \
# 32     32  chr2   95989271   95989272   rs3755519     52            T
# 33     33  chr2   95989271   95989272   rs3755519     52            T
# 14     14  chr2  135476858  135476859  rs62171396     48            C
# 29     29  chr2   95977590   95977591    rs889853     52            G
# 35     35  chr2   95989765   95989766   rs3772034     52            A
# 19     19  chr2   95742452   95742453   rs3105100     52            C
# 28     28  chr2   95977590   95977591    rs889853     52            G
# 27     27  chr2   95968204   95968205   rs7574862     52            G
# 20     20  chr2   95742677   95742678   rs3105101     52            A
# 12     12  chr2  135475959  135475960  rs62171393     48            C
# 26     26  chr2   95967745   95967746   rs9989786     52            G
# 38     38  chr2   96011837   96011838   rs6750542     52            G
# 34     34  chr2   95989271   95989272   rs3755519     52            T
# 4       4  chr2  135469768  135469769   rs6747870     48            A
# 15     15  chr2  135520533  135520534  rs13033373     48            T
# 7       7  chr2  135470055  135470056  rs17733977     48            G
# 8       8  chr2  135475195  135475196   rs4954169     48            T
# 23     23  chr2   95926153   95926154   rs1966272     52            A
# 13     13  chr2  135476834  135476835  rs62171395     48            C
# 0       0  chr2  102353344  102353345   rs7569049     47            T
#
#    minor_allele  major_score  minor_score     delta
# 32            A     1.694925     2.662038  0.967114
# 33            C     1.694925     2.528420  0.833495
# 14            T     0.487326     1.153433  0.666107
# 29            A    -0.628141    -0.061879  0.566262
# 35            G     1.296865     1.846200  0.549334
# 19            A     1.456490     1.914332  0.457842
# 28            T    -0.628141    -0.216798  0.411342
# 27            A     1.716061     2.118486  0.402425
# 20            C     3.870673     4.208459  0.337786
# 12            G     1.618551     1.944404  0.325853
# 26            A     0.817898     1.092088  0.274191
# 38            C     0.642113     0.889550  0.247437
# 34            G     1.694925     1.913190  0.218266
# 4             G     1.289796     1.430258  0.140462
# 15            C     0.963141     1.082589  0.119448
# 7             A     2.510324     2.620226  0.109902
# 8             C     1.544833     1.654716  0.109883
# 23            C     0.887918     0.977781  0.089863
# 13            G     1.082580     1.165253  0.082672
# 0             G     1.126689     1.208915  0.082226

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GGGTGCAGGAGTGCTCTCTG
# GGGTGCAGGA | GTGCTCTCTG
# GGGTGCAGGCGTGCTCTCTG
# GGGTGCAGGC | GTGCTCTCTG
# ACAGGCGGCTCTGGCAGAGC
# ACAGGCGGCT | CTGGCAGAGC
# ATGAGTGAGATCCACATGCA
# ATGAGTGAGA | TCCACATGCA
# AGGCAGAGGGAGCCCGCGGC
# AGGCAGAGGG | AGCCCGCGGC

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:1]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  32  Importance:  2.662038033  RSID:  rs3755519 chr2 :  95989271  -  95989272  Locus:  52
# Minor Allele:  A
# Index:  32  Importance:  1.69492451  RSID:  rs3755519
# Major Allele:  T
# Index:  32  Delta:  0.9671135229999999  RSID:  rs3755519
# Minor - Major:  A - T

# %% [markdown]
# # Fold 2

# %%
cluster = '1'
fold = '2'
peak = 'overlap'
gwas = 'Nalls'

# %% [markdown]
# ## Prepare Reference Alleles

# %%
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 22

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 22

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(10)
# Out:
#     index    chr      start        end        rsid  locus major_allele  \
# 5       5   chr3  122177845  122177846  rs56118506     53            C
# 15     15   chr3   49004722   49004723   rs6446196     59            G
# 16     16   chr3   49004722   49004723   rs6446196     59            G
# 11     11   chr3   48935582   48935583   rs7431710     59            A
# 2       2  chr20    5986949    5986950   rs6085343     46            G
# 13     13   chr3   48956861   48956862   rs9884022     59            C
# 10     10   chr3   48935582   48935583   rs7431710     59            A
# 7       7   chr3  161090615  161090616   rs2054710     55            C
# 20     20   chr3   49045354   49045355  rs13316620     59            C
# 8       8   chr3  161090615  161090616   rs2054710     55            C
#
#    minor_allele  major_score  minor_score     delta
# 5             T     0.995201     0.569913 -0.425288
# 15            A     1.872489     1.551053 -0.321436
# 16            T     1.872489     1.562618 -0.309872
# 11            C     0.508295     0.229955 -0.278340
# 2             A     2.351920     2.181746 -0.170174
# 13            T     2.402353     2.263598 -0.138755
# 10            G     0.508295     0.388884 -0.119411
# 7             G     1.309401     1.255487 -0.053915
# 20            T     1.594618     1.584733 -0.009885
# 8             T     1.309401     1.315852  0.006451

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[5:6]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# AATATCCCGCAGCCCGCGGC
# AATATCCCGC | AGCCCGCGGC

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[5:6]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  13  Importance:  2.4023530159  RSID:  rs9884022   chr3 : 48956861 - 48956862  Locus:  59
# Major Allele:  C
# Index:  13  Importance:  2.2635976032  RSID:  rs9884022
# Minor Allele:  T
# Index:  13  Delta:  -0.13875541270000014  RSID:  rs9884022
# Minor - Major:  T - C

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(20)
# Out:
#     index    chr      start        end         rsid  locus major_allele  \
# 21     21   chr5  133929997  133929998  rs111722920     69            T
# 8       8  chr16   30969556   30969557   rs62055866     33            C
# 5       5  chr16   30953201   30953202    rs1458202     33            A
# 3       3  chr16   30946505   30946506   rs10782002     33            G
# 9       9  chr16   31017553   31017554    rs7203999     33            C
# 10     10  chr16   31021077   31021078    rs7184567     33            C
# 20     20   chr5  133922900  133922901   rs17167630     69            T
# 15     15   chr5  102307591  102307592    rs6881225     67            T
# 4       4  chr16   30953201   30953202    rs1458202     33            A
# 19     19   chr5  102560369  102560370     rs246913     67            G
# 22     22   chr5  133929997  133929998  rs111722920     69            T
# 13     13  chr16   31044896   31044897   rs12445650     33            G
# 6       6  chr16   30968588   30968589    rs4889599     33            T
# 1       1  chr16   28937258   28937259    rs4072402     32            C
# 7       7  chr16   30968588   30968589    rs4889599     33            T
# 12     12  chr16   31044682   31044683   rs58726213     33            A
# 23     23   chr5  133930156  133930157  rs113661575     69            G
# 16     16   chr5  102345915  102345916    rs1826673     67            G
# 0       0  chr16   28937258   28937259    rs4072402     32            C
# 18     18   chr5  102456303  102456304      rs26524     67            A
#
#    minor_allele  major_score  minor_score     delta
# 21            C     0.264789     0.714536  0.449747
# 8             G     1.337324     1.713314  0.375990
# 5             C    -0.159508     0.212019  0.371527
# 3             A     0.382916     0.710447  0.327531
# 9             T     1.033396     1.349247  0.315852
# 10            T    -0.944763    -0.631275  0.313488
# 20            C     0.865742     1.094397  0.228655
# 15            C     4.258793     4.468843  0.210050
# 4             G    -0.159508     0.040237  0.199745
# 19            C     1.734870     1.872573  0.137703
# 22            G     0.264789     0.380215  0.115426
# 13            A     2.233028     2.310007  0.076979
# 6             C     3.140493     3.201023  0.060530
# 1             A     0.470375     0.522405  0.052030
# 7             G     3.140493     3.185239  0.044746
# 12            G     2.452248     2.488004  0.035757
# 23            A     0.900932     0.842463 -0.058469
# 16            A     1.406975     1.347818 -0.059157
# 0             T     0.470375     0.366782 -0.103593
# 18            G     1.161823     0.975996 -0.185827

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GCTTCTTAATTGCAGCCTCA
# gccaccccatccagagcctg
# gaactagcatgtgatcaggg

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  2  Importance:  1.3360260913000002  RSID:  rs1532278 chr8 :  27466314  -  27466315  Locus:  161
# Minor Allele:  T
# Index:  2  Importance:  1.3360260913000002  RSID:  rs1532278
# Major Allele:  C
# Index:  2  Delta:  0.15722050499999995  RSID:  rs1532278
# Minor - Major:  T - C
# Index:  0  Importance:  0.3074199905000001  RSID:  rs1532276 chr8 :  27466156  -  27466157  Locus:  161
# Minor Allele:  T
# Index:  0  Importance:  0.3074199905000001  RSID:  rs1532276
# Major Allele:  C
# Index:  0  Delta:  0.07633222330000006  RSID:  rs1532276
# Minor - Major:  T - C
# Index:  1  Importance:  0.57997495832  RSID:  rs1532277 chr8 :  27466180  -  27466181  Locus:  161
# Minor Allele:  T
# Index:  1  Importance:  0.57997495832  RSID:  rs1532277
# Major Allele:  C
# Index:  1  Delta:  -0.06448007377999998  RSID:  rs1532277
# Minor - Major:  T - C
