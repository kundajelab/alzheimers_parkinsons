# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.insert(0, "/users/soumyak/alzheimers_parkinsons/clusters_gkmsvm")
from viz_preprocess import *
from viz_sequence import *
import pysam
import pickle
import random
import modisco
import warnings
import plotnine
import pybedtools
import numpy as np
import tabix as tb
import pandas as pd
from plotnine import *
from pandas import Series
from kerasAC.splits import *
from matplotlib import pyplot as plt
from deeplift.dinuc_shuffle import dinuc_shuffle

from dragonn.interpret import * 
from dragonn.vis import *
from dragonn.utils import *

np.random.seed(1234)
plt.style.use('default')
# Out:
# TF-MoDISco is using the TensorFlow backend.
# Using TensorFlow backend.

# %% [markdown]
# # Fold 2

# %%
cluster = '24'
fold = '0'
peak = 'overlap'
gwas = 'Nalls'

# %% [markdown]
# ## Prepare Reference Alleles

# %%
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 8

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 8

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(20)
# Out:
#    index   chr      start        end         rsid  locus major_allele  \
# 1      1  chr1  155108166  155108167   rs12726330     11            G
# 6      6  chr1  171711151  171711152   rs12119232     13            A
# 3      3  chr1  161470041  161470042    rs7551957     12            T
# 2      2  chr1  155108166  155108167   rs12726330     11            G
# 4      4  chr1  161470041  161470042    rs7551957     12            T
# 0      0  chr1  154898184  154898185  rs114138760     11            G
# 7      7  chr1  205719531  205719532     rs823114     15            G
# 5      5  chr1  171710404  171710405    rs2298914     13            C
#
#   minor_allele  major_score  minor_score     delta
# 1            A     1.368119     1.118307 -0.249812
# 6            C     2.256810     2.141392 -0.115418
# 3            C     0.173876     0.178222  0.004346
# 2            C     1.368119     1.392576  0.024457
# 4            G     0.173876     0.208760  0.034884
# 0            C     0.010136     0.200689  0.190554
# 7            A     2.056761     2.287140  0.230379
# 5            T     0.602418     0.862104  0.259686

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[10:11]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GCGCATTTTTGTGAAACATC
# GCGCATTTTT | GTGAAACATC

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[10:11]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  8  Importance:  4.815545315  RSID:  rs2619356   chr4 : 90750843 - 90750844  Locus:  209
# Major Allele:  T
# Index:  8  Importance:  4.656748243  RSID:  rs2619356
# Minor Allele:  C
# Index:  8  Delta:  -0.1587970719999996  RSID:  rs2619356
# Minor - Major:  C - T

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(10)
# Out:
#    index   chr      start        end         rsid  locus major_allele  \
# 5      5  chr1  171710404  171710405    rs2298914     13            C
# 7      7  chr1  205719531  205719532     rs823114     15            G
# 0      0  chr1  154898184  154898185  rs114138760     11            G
# 4      4  chr1  161470041  161470042    rs7551957     12            T
# 2      2  chr1  155108166  155108167   rs12726330     11            G
# 3      3  chr1  161470041  161470042    rs7551957     12            T
# 6      6  chr1  171711151  171711152   rs12119232     13            A
# 1      1  chr1  155108166  155108167   rs12726330     11            G
#
#   minor_allele  major_score  minor_score     delta
# 5            T     0.602418     0.862104  0.259686
# 7            A     2.056761     2.287140  0.230379
# 0            C     0.010136     0.200689  0.190554
# 4            G     0.173876     0.208760  0.034884
# 2            C     1.368119     1.392576  0.024457
# 3            C     0.173876     0.178222  0.004346
# 6            C     2.256810     2.141392 -0.115418
# 1            A     1.368119     1.118307 -0.249812

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# GCAAAGGCTTTCCTTTTCCC
# GCAAAGGCTT | TCCTTTTCCC
# AGAGCGCACAGCCGCAAAAC
# AGAGCGCACA | GCCGCAAAAC
# CCTGGGAAACAGACTTAACC
# CCTGGGAAAC | AGACTTAACC
# AGCACCCAAGAGATACTTGC
# AGCACCCAAG | AGATACTTGC
# TCTGGACCACGGTACTGGGA
# TCTGGACCAC | GGTACTGGGA

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[1:2]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  7  Importance:  2.2871399219999997  RSID:  rs823114 chr1 :  205719531  -  205719532  Locus:  15
# Minor Allele:  A
# Index:  7  Importance:  2.056760825  RSID:  rs823114
# Major Allele:  G
# Index:  7  Delta:  0.2303790969999997  RSID:  rs823114
# Minor - Major:  A - G

# %% [markdown]
# # Fold 4

# %%
cluster = '6'
fold = '4'
peak = 'overlap'
gwas = 'Nalls'

# %% [markdown]
# ## Prepare Reference Alleles

# %%
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 15

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 15

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(10)
# Out:
#     index    chr      start        end         rsid  locus major_allele  \
# 10     10   chr5  102456253  102456254      rs26523     67            C
# 0       0  chr16   30934074   30934075    rs3813020     33            A
# 14     14   chr5  133936193  133936194  rs142547906     69            G
# 7       7  chr16   50743330   50743331   rs11647841     34            G
# 9       9   chr5  102334246  102334247   rs62362544     67            C
# 11     11   chr5  102456303  102456304      rs26524     67            A
# 5       5  chr16   31044682   31044683   rs58726213     33            A
# 2       2  chr16   30953201   30953202    rs1458202     33            A
# 1       1  chr16   30953201   30953202    rs1458202     33            A
# 4       4  chr16   30968588   30968589    rs4889599     33            T
#
#    minor_allele  major_score  minor_score     delta
# 10            T     0.448252     0.075272 -0.372980
# 0             G     1.992621     1.752525 -0.240096
# 14            A    -0.573360    -0.757380 -0.184020
# 7             A     0.791106     0.658247 -0.132859
# 9             T    -0.165585    -0.295732 -0.130147
# 11            G     0.924684     0.824653 -0.100031
# 5             G     1.550561     1.464303 -0.086258
# 2             C    -0.242565    -0.295920 -0.053355
# 1             G    -0.242565    -0.274167 -0.031602
# 4             G     2.389365     2.409422  0.020056

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# TCTGACACACATTGCTCTGC
# TCTGACACAC | ATTGCTCTGC

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  0  Importance:  0.5837461271  RSID:  rs11762262   chr7 : 143107875 - 143107876  Locus:  160
# Major Allele:  C
# Index:  0  Importance:  0.5144582294000001  RSID:  rs11762262
# Minor Allele:  T
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-d4d402c9c0dc> in <module>
#       6     print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
#       7     print("Minor Allele: ", gwas_minor[idx])
# ----> 8     a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
#       9     print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
#      10     print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_weights(array, figsize, height_padding_factor, length_padding, subticks_frequency, colors, plot_funcs, highlight, ylim, xlim, ylabel)
#     160         ylim=ylim,
#     161         xlim=xlim,
# --> 162         ylabel=ylabel)
#     163     plt.show()
#     164     return ylim
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_weights_given_ax(ax, array, height_padding_factor, length_padding, subticks_frequency, highlight, colors, plot_funcs, ylim, xlim, ylabel)
#     102                 height_so_far = negative_height_so_far
#     103                 negative_height_so_far += letter[1]
# --> 104             plot_func(ax=ax, base=height_so_far, left_edge=i, height=letter[1], color=color)
#     105         max_pos_height = max(max_pos_height, positive_height_so_far)
#     106         min_neg_height = min(min_neg_height, negative_height_so_far)
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_g(ax, base, left_edge, height, color)
#      49 def plot_g(ax, base, left_edge, height, color):
#      50     ax.add_patch(matplotlib.patches.Ellipse(xy=[left_edge+0.65, base+0.5*height], width=1.3, height=height,
# ---> 51                                             facecolor=color, edgecolor=color))
#      52     ax.add_patch(matplotlib.patches.Ellipse(xy=[left_edge+0.65, base+0.5*height], width=0.7*1.3, height=0.7*height,
#      53                                             facecolor='white', edgecolor='white'))
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2032         self._set_artist_props(p)
#    2033         if p.get_clip_path() is None:
# -> 2034             p.set_clip_path(self.patch)
#    2035         self._update_patch_limits(p)
#    2036         self.patches.append(p)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in set_clip_path(self, path, transform)
#     700         # will be hit at least once.
#     701         self.pchanged()
# --> 702         self.stale = True
#     703
#     704     def get_alpha(self):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/artist.py in stale(self, val)
#     238             return
#     239
# --> 240         if val and self.stale_callback is not None:
#     241             self.stale_callback(self, val)
#     242
#
# KeyboardInterrupt:

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(10)
# Out:
#    index   chr     start       end        rsid  locus major_allele  \
# 1      1  chr1  40349427  40349428  rs61781270    152            G
# 0      0  chr1  40349427  40349428  rs61781270    152            G
#
#   minor_allele  major_score  minor_score     delta
# 1            C     -0.22931    -0.130908  0.098402
# 0            A     -0.22931    -0.581894 -0.352584

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# CTTTGCTGCCATCTGCTGGG
# CTTTGCTGCC | ATCTGCTGGG
# AAAATGTAGAAGCAAAACAT
# AAAATGTAGA | AGCAAAACAT
# CCCCATTCCGGCCACACTGC
# CCCCATTCCG | GCCACACTGC
# GGGGAACAGGAAGGTTGATC
# GGGGAACAGG | AAGGTTGATC
# GAAAAGGGAAAAGGGTCCTT
# GAAAAGGGAA | AAGGGTCCTT

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  20  Importance:  1.6565424143  RSID:  rs636317 chr11 :  60019149  -  60019150  Locus:  149
# Minor Allele:  C
# Index:  20  Importance:  1.6565424143  RSID:  rs636317
# Major Allele:  T
# Index:  20  Delta:  1.6427298736999996  RSID:  rs636317
# Minor - Major:  C - T
# Index:  40  Importance:  1.0946893402  RSID:  rs10792832 chr11 :  85867874  -  85867875  Locus:  150
# Minor Allele:  A
# Index:  40  Importance:  1.0946893402  RSID:  rs10792832
# Major Allele:  G
# Index:  40  Delta:  0.3757902812  RSID:  rs10792832
# Minor - Major:  A - G
# Index:  17  Importance:  1.7050295674000002  RSID:  rs584469 chr11 :  59988861  -  59988862  Locus:  149
# Minor Allele:  G
# Index:  17  Importance:  1.7050295674000002  RSID:  rs584469
# Major Allele:  T
# Index:  17  Delta:  0.3380872598999993  RSID:  rs584469
# Minor - Major:  G - T
# Index:  39  Importance:  2.3639307448  RSID:  rs10792831 chr11 :  85852978  -  85852979  Locus:  150
# Minor Allele:  G
# Index:  39  Importance:  2.3639307448  RSID:  rs10792831
# Major Allele:  A
# Index:  39  Delta:  0.3372900018999996  RSID:  rs10792831
# Minor - Major:  G - A
# Index:  0  Importance:  -0.39246520100000004  RSID:  rs12146565 chr11 :  47398962  -  47398963  Locus:  148
# Minor Allele:  A
# Index:  0  Importance:  -0.39246520100000004  RSID:  rs12146565
# Major Allele:  G
# Index:  0  Delta:  0.322842067  RSID:  rs12146565
# Minor - Major:  A - G

# %% [markdown]
# # Fold 9

# %% [markdown]
# ## Prepare Reference Alleles

# %%
cluster = '24'
fold = '9'
peak = 'overlap'
gwas = 'Kunkle'
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 3

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 3

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(10)
# Out:
#    index   chr     start       end       rsid  locus major_allele  \
# 1      1  chr8  27226789  27226790   rs755951    161            A
# 2      2  chr8  27456252  27456253  rs2279590    161            C
# 0      0  chr8  27226789  27226790   rs755951    161            A
#
#   minor_allele  major_score  minor_score     delta
# 1            T    -0.594121    -0.681722 -0.087600
# 2            T     2.024471     2.291536  0.267065
# 0            C    -0.594121     0.172130  0.766251

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# TTCACTGGCATGTAGGGGGA
# TTCACTGGCA | TGTAGGGGGA
# CCTCCTGCTCCTCCAAGGAA
# CCTCCTGCTC | CTCCAAGGAA
# TTCACTGGCATGTAGGGGGA
# TTCACTGGCA | TGTAGGGGGA

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  1  Importance:  -0.5941214895000001  RSID:  rs755951   chr8 : 27226789 - 27226790  Locus:  161
# Major Allele:  A
# Index:  1  Importance:  -0.6817219513999999  RSID:  rs755951
# Minor Allele:  T
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-d4d402c9c0dc> in <module>
#       6     print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
#       7     print("Minor Allele: ", gwas_minor[idx])
# ----> 8     a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
#       9     print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
#      10     print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
#
# ~/alzheimers_parkinsons/clusters_gkmsvm/viz_sequence.py in plot_weights(array, figsize, height_padding_factor, length_padding, subticks_frequency, colors, plot_funcs, highlight, ylim, xlim, ylabel)
#     161         xlim=xlim,
#     162         ylabel=ylabel)
# --> 163     plt.show()
#     164     return ylim
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </users/soumyak/miniconda3/envs/dragonn/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2247
#    2248             restore_bbox = tight_bbox.adjust_bbox(self.figure, bbox_inches,
# -> 2249                                                   canvas.fixed_dpi)
#    2250
#    2251             _bbox_inches_restore = (bbox_inches, restore_bbox)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/tight_bbox.py in adjust_bbox(fig, bbox_inches, fixed_dpi)
#      64     w1, h1 = fig.bbox.width * dpi_scale, fig.bbox.height * dpi_scale
#      65     fig.transFigure._boxout = Bbox.from_bounds(-x0, -y0, w1, h1)
# ---> 66     fig.transFigure.invalidate()
#      67
#      68     fig.bbox = TransformedBbox(fig.bbox_inches, tr)
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in invalidate(self)
#     138         if self.is_affine:
#     139             value = self.INVALID_AFFINE
# --> 140         return self._invalidate_internal(value, invalidating_node=self)
#     141
#     142     def _invalidate_internal(self, value, invalidating_node):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     165                 if parent is not None:
#     166                     parent._invalidate_internal(
# --> 167                         value=value, invalidating_node=self)
#     168
#     169     def set_children(self, *children):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     165                 if parent is not None:
#     166                     parent._invalidate_internal(
# --> 167                         value=value, invalidating_node=self)
#     168
#     169     def set_children(self, *children):
#
# ~/miniconda3/envs/dragonn/lib/python3.7/site-packages/matplotlib/transforms.py in _invalidate_internal(self, value, invalidating_node)
#     162             for parent in list(six.itervalues(self._parents)):
#     163                 # Dereference the weak reference
# --> 164                 parent = parent()
#     165                 if parent is not None:
#     166                     parent._invalidate_internal(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(10)
# Out:
#     index    chr     start       end        rsid  locus major_allele  \
# 20     20  chr11  60019149  60019150    rs636317    149            T
# 40     40  chr11  85867874  85867875  rs10792832    150            G
# 17     17  chr11  59988861  59988862    rs584469    149            T
# 39     39  chr11  85852978  85852979  rs10792831    150            A
# 0       0  chr11  47398962  47398963  rs12146565    148            G
# 1       1  chr11  47399601  47399602   rs2278890    148            G
# 26     26  chr11  60031398  60031399  rs10736700    149            C
# 3       3  chr11  47416635  47416636  rs55876153    148            G
# 27     27  chr11  60031398  60031399  rs10736700    149            C
# 7       7  chr11  47429903  47429904   rs7947450    148            G
#
#    minor_allele  major_score  minor_score     delta
# 20            C     1.656542     3.299272  1.642730
# 40            A     1.094689     1.470480  0.375790
# 17            G     1.705030     2.043117  0.338087
# 39            G     2.363931     2.701221  0.337290
# 0             A    -0.392465    -0.069623  0.322842
# 1             A     0.433770     0.662054  0.228284
# 26            T     0.172574     0.367345  0.194772
# 3             C     0.170297     0.362318  0.192021
# 27            A     0.172574     0.356640  0.184066
# 7             A     3.067069     3.248758  0.181689

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# CTTTGCTGCCATCTGCTGGG
# CTTTGCTGCC | ATCTGCTGGG
# AAAATGTAGAAGCAAAACAT
# AAAATGTAGA | AGCAAAACAT
# CCCCATTCCGGCCACACTGC
# CCCCATTCCG | GCCACACTGC
# GGGGAACAGGAAGGTTGATC
# GGGGAACAGG | AAGGTTGATC
# GAAAAGGGAAAAGGGTCCTT
# GAAAAGGGAA | AAGGGTCCTT

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  20  Importance:  1.6565424143  RSID:  rs636317 chr11 :  60019149  -  60019150  Locus:  149
# Minor Allele:  C
# Index:  20  Importance:  1.6565424143  RSID:  rs636317
# Major Allele:  T
# Index:  20  Delta:  1.6427298736999996  RSID:  rs636317
# Minor - Major:  C - T
# Index:  40  Importance:  1.0946893402  RSID:  rs10792832 chr11 :  85867874  -  85867875  Locus:  150
# Minor Allele:  A
# Index:  40  Importance:  1.0946893402  RSID:  rs10792832
# Major Allele:  G
# Index:  40  Delta:  0.3757902812  RSID:  rs10792832
# Minor - Major:  A - G
# Index:  17  Importance:  1.7050295674000002  RSID:  rs584469 chr11 :  59988861  -  59988862  Locus:  149
# Minor Allele:  G
# Index:  17  Importance:  1.7050295674000002  RSID:  rs584469
# Major Allele:  T
# Index:  17  Delta:  0.3380872598999993  RSID:  rs584469
# Minor - Major:  G - T
# Index:  39  Importance:  2.3639307448  RSID:  rs10792831 chr11 :  85852978  -  85852979  Locus:  150
# Minor Allele:  G
# Index:  39  Importance:  2.3639307448  RSID:  rs10792831
# Major Allele:  A
# Index:  39  Delta:  0.3372900018999996  RSID:  rs10792831
# Minor - Major:  G - A
# Index:  0  Importance:  -0.39246520100000004  RSID:  rs12146565 chr11 :  47398962  -  47398963  Locus:  148
# Minor Allele:  A
# Index:  0  Importance:  -0.39246520100000004  RSID:  rs12146565
# Major Allele:  G
# Index:  0  Delta:  0.322842067  RSID:  rs12146565
# Minor - Major:  A - G

# %% [markdown]
# # Fold 7

# %% [markdown]
# ## Prepare Reference Alleles

# %%
cluster = '24'
fold = '7'
peak = 'overlap'
gwas = 'Kunkle'
gwas_bed = pd.read_csv('/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.txt', header=None, sep='\t')
gwas_chrom = gwas_bed[0].tolist()
gwas_start = gwas_bed[1].tolist()
gwas_end = gwas_bed[2].tolist()
gwas_rsid = gwas_bed[3].tolist()
gwas_locus = gwas_bed[5].to_list()
gwas_major = gwas_bed[6].tolist()
gwas_minor = gwas_bed[7].tolist()

major_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.major.fasta'
major_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_major_hyp_scores.txt'

major_seqs = [x.rstrip() for (i,x) in enumerate(open(major_fasta)) if i%2==1]
major_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in major_seqs if ('N' not in x)]

print("Num onehot sequences:", len(major_onehot))

major_hyp_scores = [w[0] for w in zip([
    np.array([[float(z) for z in y.split(",")]
                for y in x.rstrip().split("\t")[2].split(";")])
    for x in open(major_hyp_file)], major_seqs) if 'N' not in w[1]]

major_imp_scores = get_impscores(major_hyp_scores, major_onehot)

assert (np.max([np.max(np.abs(z*y - x))
                for x,y,z in zip(major_imp_scores,
                                 major_onehot,
                                 major_hyp_scores)])) == 0

major_normed_imp_scores, major_normed_hyp_scores = normalize_scores(
    impscores=major_imp_scores, hyp_impscores=major_hyp_scores, onehot_data=major_onehot)
# Out:
# Num onehot sequences: 41

# %% [markdown]
# ## Prepare Alternate Alleles

# %%
minor_fasta = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/gwas/'+peak+'/'+gwas+'.minor.fasta'
minor_hyp_file = '/mnt/lab_data3/soumyak/adpd/clusters_gkmsvm/Cluster'+cluster+'/fold'+fold+'/explain/output/'+gwas+'_'+peak+'_minor_hyp_scores.txt'
                                                                                
minor_seqs = [x.rstrip() for (i,x) in enumerate(open(minor_fasta)) if i%2==1]       
minor_onehot = [np.array(one_hot_encode_along_channel_axis(x)) for x in minor_seqs if ('N' not in x)]
                                                                                
print("Num onehot sequences:", len(minor_onehot))                                 
                                                                                
minor_hyp_scores = [w[0] for w in zip([                                           
    np.array([[float(z) for z in y.split(",")]                                  
                for y in x.rstrip().split("\t")[2].split(";")])                 
    for x in open(minor_hyp_file)], minor_seqs) if 'N' not in w[1]]                 
                                                                                
minor_imp_scores = get_impscores(minor_hyp_scores, minor_onehot)                      
                                                                                
assert (np.max([np.max(np.abs(z*y - x))                                         
                for x,y,z in zip(minor_imp_scores,                                
                                 minor_onehot,                                    
                                 minor_hyp_scores)])) == 0                        
                                                                                
minor_normed_imp_scores, minor_normed_hyp_scores = normalize_scores(                
    impscores=minor_imp_scores, hyp_impscores=minor_hyp_scores, onehot_data=minor_onehot)
# Out:
# Num onehot sequences: 41

# %% [markdown]
# ## Find Alternate Alleles that Break Accessibility

# %%
seq_dict = {'index':[], 'chr':[], 'start':[], 'end':[], 'rsid': [], 'locus':[], 'major_allele':[], 'minor_allele':[], 'major_score':[], 'minor_score':[], 'delta':[]}

for i,j in enumerate(gwas_chrom):
    seq_dict['index'].append(i)
    seq_dict['chr'].append(gwas_chrom[i])
    seq_dict['start'].append(gwas_start[i])
    seq_dict['end'].append(gwas_end[i])
    seq_dict['rsid'].append(gwas_rsid[i])
    seq_dict['locus'].append(gwas_locus[i])
    seq_dict['major_allele'].append(gwas_major[i])
    seq_dict['minor_allele'].append(gwas_minor[i])
    seq_dict['major_score'].append(np.sum(major_imp_scores[i][400:600]))
    seq_dict['minor_score'].append(np.sum(minor_imp_scores[i][400:600]))
    seq_dict['delta'].append(np.sum(minor_imp_scores[i][400:600]) - np.sum(major_imp_scores[i][400:600]))
    
seq_df = pd.DataFrame.from_dict(seq_dict)
seq_df.sort_values(by='delta', ascending=True, inplace=True)
seq_df.head(10)
# Out:
#     index    chr     start       end        rsid  locus major_allele  \
# 33     33  chr11  85779161  85779162   rs2509609    150            G
# 32     32  chr11  85779161  85779162   rs2509609    150            G
# 14     14  chr11  59951432  59951433    rs632185    149            G
# 19     19  chr11  60002934  60002935    rs718376    149            G
# 28     28  chr11  60031475  60031476  rs10736701    149            T
# 25     25  chr11  60031269  60031270   rs7128450    149            C
# 30     30  chr11  60078474  60078475  rs61900467    149            C
# 13     13  chr11  47902882  47902883  rs12364432    148            G
# 37     37  chr11  85828550  85828551    rs474479    150            G
# 24     24  chr11  60027308  60027309   rs1365247    149            C
#
#    minor_allele  major_score  minor_score     delta
# 33            A     1.863188     1.282015 -0.581173
# 32            C     1.863188     1.345971 -0.517218
# 14            A     1.649759     1.298187 -0.351572
# 19            A     1.790668     1.539173 -0.251495
# 28            C     0.877373     0.644954 -0.232419
# 25            G     1.058709     0.840660 -0.218049
# 30            T     1.028374     0.843297 -0.185077
# 13            C     2.041510     1.858701 -0.182809
# 37            C     1.476450     1.305661 -0.170789
# 24            T     2.836531     2.688468 -0.148063

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(major_seqs[idx][490:510])
    print(major_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# AGGGATGGGGGAAGCAGCTA
# AGGGATGGGG | GAAGCAGCTA
# AGGGATGGGGGAAGCAGCTA
# AGGGATGGGG | GAAGCAGCTA
# CTGACTTCAGTGTATCAGGC
# CTGACTTCAG | TGTATCAGGC
# AGGACACTTGCAGTTTCATA
# AGGACACTTG | CAGTTTCATA
# GGACTGATCTTGTAACAAAG
# GGACTGATCT | TGTAACAAAG

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx], 
          ' ', seq_df.at[idx, 'chr'], ':', seq_df.at[idx, 'start'], '-', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Major Allele: ", gwas_major[idx])
    ylim = plot_weights(major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx])
    print("Minor Allele: ", gwas_minor[idx])
    a = plot_weights(minor_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  33  Importance:  1.8631882792  RSID:  rs2509609   chr11 : 85779161 - 85779162  Locus:  150
# Major Allele:  G
# Index:  33  Importance:  1.2820154165000002  RSID:  rs2509609
# Minor Allele:  A
# Index:  33  Delta:  -0.5811728626999999  RSID:  rs2509609
# Minor - Major:  A - G
# Index:  32  Importance:  1.8631882792  RSID:  rs2509609   chr11 : 85779161 - 85779162  Locus:  150
# Major Allele:  G
# Index:  32  Importance:  1.3459706764  RSID:  rs2509609
# Minor Allele:  C
# Index:  32  Delta:  -0.5172176028000002  RSID:  rs2509609
# Minor - Major:  C - G
# Index:  14  Importance:  1.6497586016  RSID:  rs632185   chr11 : 59951432 - 59951433  Locus:  149
# Major Allele:  G
# Index:  14  Importance:  1.2981870538  RSID:  rs632185
# Minor Allele:  A
# Index:  14  Delta:  -0.3515715478000001  RSID:  rs632185
# Minor - Major:  A - G
# Index:  19  Importance:  1.7906678049999998  RSID:  rs718376   chr11 : 60002934 - 60002935  Locus:  149
# Major Allele:  G
# Index:  19  Importance:  1.5391732237999998  RSID:  rs718376
# Minor Allele:  A
# Index:  19  Delta:  -0.2514945812  RSID:  rs718376
# Minor - Major:  A - G
# Index:  28  Importance:  0.8773725320000001  RSID:  rs10736701   chr11 : 60031475 - 60031476  Locus:  149
# Major Allele:  T
# Index:  28  Importance:  0.6449537349000001  RSID:  rs10736701
# Minor Allele:  C
# Index:  28  Delta:  -0.23241879710000002  RSID:  rs10736701
# Minor - Major:  C - T

# %% [markdown]
# ## Find Alternate Alleles that Improve Accessibility

# %%
seq_df.sort_values(by='delta', ascending=False, inplace=True)
seq_df.head(10)
# Out:
#     index    chr     start       end        rsid  locus major_allele  \
# 20     20  chr11  60019149  60019150    rs636317    149            T
# 40     40  chr11  85867874  85867875  rs10792832    150            G
# 17     17  chr11  59988861  59988862    rs584469    149            T
# 39     39  chr11  85852978  85852979  rs10792831    150            A
# 0       0  chr11  47398962  47398963  rs12146565    148            G
# 1       1  chr11  47399601  47399602   rs2278890    148            G
# 26     26  chr11  60031398  60031399  rs10736700    149            C
# 3       3  chr11  47416635  47416636  rs55876153    148            G
# 27     27  chr11  60031398  60031399  rs10736700    149            C
# 7       7  chr11  47429903  47429904   rs7947450    148            G
#
#    minor_allele  major_score  minor_score     delta
# 20            C     1.656542     3.299272  1.642730
# 40            A     1.094689     1.470480  0.375790
# 17            G     1.705030     2.043117  0.338087
# 39            G     2.363931     2.701221  0.337290
# 0             A    -0.392465    -0.069623  0.322842
# 1             A     0.433770     0.662054  0.228284
# 26            T     0.172574     0.367345  0.194772
# 3             C     0.170297     0.362318  0.192021
# 27            A     0.172574     0.356640  0.184066
# 7             A     3.067069     3.248758  0.181689

# %% [markdown]
# ## Get 10 bp around SNP

# %%
ref_seq = pysam.FastaFile('/mnt/data/pipeline_genome_data/hg19/male.hg19.fa')
for idx in seq_df.iloc[:5]['index']:
    print(minor_seqs[idx][490:510])
    print(minor_seqs[idx][490:500], '|', major_seqs[idx][500:510])
# Out:
# CTTTGCTGCCATCTGCTGGG
# CTTTGCTGCC | ATCTGCTGGG
# AAAATGTAGAAGCAAAACAT
# AAAATGTAGA | AGCAAAACAT
# CCCCATTCCGGCCACACTGC
# CCCCATTCCG | GCCACACTGC
# GGGGAACAGGAAGGTTGATC
# GGGGAACAGG | AAGGTTGATC
# GAAAAGGGAAAAGGGTCCTT
# GAAAAGGGAA | AAGGGTCCTT

# %% [markdown]
# ## Visualize Top Sequences

# %%
for idx in seq_df.iloc[:5]['index']:
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'minor_score'], " RSID: ", gwas_rsid[idx], 
          seq_df.at[idx, 'chr'], ': ', seq_df.at[idx, 'start'], ' - ', seq_df.at[idx, 'end'], " Locus: ", seq_df.at[idx, 'locus'])
    print("Minor Allele: ", gwas_minor[idx])
    ylim = plot_weights(minor_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
    print("Index: ", idx, " Importance: ", seq_df.at[idx, 'major_score'], " RSID: ", gwas_rsid[idx])
    print("Major Allele: ", gwas_major[idx])
    a = plot_weights(major_imp_scores[idx], subticks_frequency=10, ylim=ylim, xlim=(400,600))
    print("Index: ", idx, " Delta: ", seq_df.at[idx, 'delta'], " RSID: ", gwas_rsid[idx])
    print("Minor - Major: ", gwas_minor[idx] + ' - ' + gwas_major[idx])
    a = plot_weights(minor_imp_scores[idx] - major_imp_scores[idx], subticks_frequency=10, xlim=(400,600))
# Out:
# Index:  20  Importance:  1.6565424143  RSID:  rs636317 chr11 :  60019149  -  60019150  Locus:  149
# Minor Allele:  C
# Index:  20  Importance:  1.6565424143  RSID:  rs636317
# Major Allele:  T
# Index:  20  Delta:  1.6427298736999996  RSID:  rs636317
# Minor - Major:  C - T
# Index:  40  Importance:  1.0946893402  RSID:  rs10792832 chr11 :  85867874  -  85867875  Locus:  150
# Minor Allele:  A
# Index:  40  Importance:  1.0946893402  RSID:  rs10792832
# Major Allele:  G
# Index:  40  Delta:  0.3757902812  RSID:  rs10792832
# Minor - Major:  A - G
# Index:  17  Importance:  1.7050295674000002  RSID:  rs584469 chr11 :  59988861  -  59988862  Locus:  149
# Minor Allele:  G
# Index:  17  Importance:  1.7050295674000002  RSID:  rs584469
# Major Allele:  T
# Index:  17  Delta:  0.3380872598999993  RSID:  rs584469
# Minor - Major:  G - T
# Index:  39  Importance:  2.3639307448  RSID:  rs10792831 chr11 :  85852978  -  85852979  Locus:  150
# Minor Allele:  G
# Index:  39  Importance:  2.3639307448  RSID:  rs10792831
# Major Allele:  A
# Index:  39  Delta:  0.3372900018999996  RSID:  rs10792831
# Minor - Major:  G - A
# Index:  0  Importance:  -0.39246520100000004  RSID:  rs12146565 chr11 :  47398962  -  47398963  Locus:  148
# Minor Allele:  A
# Index:  0  Importance:  -0.39246520100000004  RSID:  rs12146565
# Major Allele:  G
# Index:  0  Delta:  0.322842067  RSID:  rs12146565
# Minor - Major:  A - G
