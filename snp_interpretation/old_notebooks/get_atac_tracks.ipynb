# %% [markdown]
# # Imports

# %%
import os
import sys
import math
import statistics
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import *
from decimal import Decimal
from IPython.display import Image
from matplotlib import pyplot as plt

sys.path.insert(0, '/users/soumyak/alzheimers_parkinsons/clusters_gkmsvm')
from viz_preprocess import *
from viz_sequence import *
from make_plots import *
from kerasAC.splits import *

plt.style.use('default')
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Get Significant SNPs

# %%
all_conf = pd.read_csv('/mnt/lab_data3/soumyak/adpd/sig_snps/all.sig.snps.conf.bed', sep='\t')
all_conf.sort_values(by=['chr', 'start', 'end', 'rsid', 'confidence'])
all_conf.drop_duplicates(subset=['chr', 'start', 'end', 'rsid'], inplace=True)
display(all_conf.shape)
display(all_conf)
# Out:
# (123, 13)
#        chr      start        end         rsid effect noneffect direction  \
# 0    chr17   45947293   45947294   rs62062786      G         C         +
# 1    chr19   18438073   18438074    rs2303696      C         T         +
# 2    chr17   46771150   46771151     rs199523      C         A         -
# 3     chr3   49007333   49007334    rs6781790      T         C         +
# 4     chr2   95057163   95057164     rs872580      C         A         -
# 5     chr2   95323523   95323524    rs3755519      T         A         +
# 6    chr19   44915228   44915229   rs12691088      A         G         +
# 7     chr8   22604860   22604861    rs3735901      T         C         -
# 8    chr17   45852666   45852667   rs62054825      G         A         +
# 9    chr17   45896863   45896864   rs62056782      T         C         -
# 11   chr17    4901871    4901872   rs79436576      T         C         +
# 13   chr16   30010080   30010081    rs1140239      T         C         -
# ...

# %% [markdown]
# # Get NN-specifc SNPs

# %%
nn_snps = pd.read_csv('/mnt/lab_data3/soumyak/adpd/nn_analysis/nn_only_snps.bed', sep='\t')
nn_snps.sort_values(by=['chr', 'start', 'end', 'rsid'])
nn_snps.drop_duplicates(subset=['chr', 'start', 'end', 'rsid'], inplace=True)
display(nn_snps.shape)
display(nn_snps)
# Out:
# (36, 8)
#        chr      start        end         rsid effect noneffect  cluster  fold
# 0     chr3   52661717   52661718  rs139169428      T         C        1     2
# 1     chr3   48856346   48856347    rs9840684      T         C        1     2
# 2    chr11   60251687   60251688     rs636341      A         C        1     7
# 3    chr17   45894418   45894419   rs11575895      G         A        1     7
# 4    chr17   45935736   45935737   rs17650417      T         G        1     7
# 5    chr17   45775742   45775743   rs55787105      G         A        1     7
# 6    chr17   45730954   45730955   rs62054389      G         A        1     7
# 7    chr17   46053301   46053302   rs75546272      T         A        1     7
# 8    chr17   45748111   45748112   rs75715199      G         A        1     7
# 9    chr12   40148960   40148961   rs78214347      G         A        1     8
# 10   chr10   15506037   15506038   rs10752393      G         C        1     9
# ...

# %% [markdown]
# # Generate Signal Tracks

# %%
# test_fold = []
# ten_folds = []
# fc_tracks_1kb = []
# pval_tracks_1kb = []
    
#for index, row in all_conf.iterrows():
for index, row in nn_snps.iterrows():
    chrom = row['chr']
    start = row['start'] - 500
    end = row['start'] + 500
    rsid = row['rsid']
    #test_fold.append('http://mitra.stanford.edu/kundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/123_sig_list/'+rsid)
    #ten_folds.append('http://mitra.stanford.edu/kundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/10_fold_examples/123_sig_list/'+rsid)
    ! pyGenomeTracks --tracks /mnt/lab_data3/soumyak/adpd/pytracks/fc_bigwig_snps.ini --region {chrom}:{start}-{end} -o /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/{rsid}.fc.1kb.png
    ! pyGenomeTracks --tracks /mnt/lab_data3/soumyak/adpd/pytracks/pval_bigwig_snps.ini --region {chrom}:{start}-{end} -o /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/{rsid}.pval.1kb.png
    #fc_tracks_1kb.append('http://mitra.stanford.edu/kundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/'+rsid+'.fc.1kb.png')
    #pval_tracks_1kb.append('http://mitra.stanford.edu/kundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/'+rsid+'.pval.1kb.png')

# fc_tracks_5kb = []
# pval_tracks_5kb = []

#for index, row in all_conf.iterrows():
for index, row in nn_snps.iterrows():
    chrom = row['chr']
    start = row['start'] - 2500
    end = row['start'] + 2500
    rsid = row['rsid']
    ! pyGenomeTracks --tracks /mnt/lab_data3/soumyak/adpd/pytracks/fc_bigwig_snps.ini --region {chrom}:{start}-{end} -o /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/{rsid}.fc.5kb.png
    ! pyGenomeTracks --tracks /mnt/lab_data3/soumyak/adpd/pytracks/pval_bigwig_snps.ini --region {chrom}:{start}-{end} -o /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/{rsid}.pval.5kb.png
    #fc_tracks_5kb.append('http://mitra.stanford.edu/kundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/'+rsid+'.fc.5kb.png')
    #pval_tracks_5kb.append('http://mitra.stanford.edu/kundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/'+rsid+'.pval.5kb.png')
    
# all_conf['test_fold'] = test_fold
# all_conf['10_folds'] = ten_folds
# all_conf['fc_1kb'] = fc_tracks_1kb
# all_conf['pval_1kb'] = pval_tracks_1kb
# all_conf['fc_5kb'] = fc_tracks_5kb
# all_conf['pval_5kb'] = pval_tracks_5kb
# Out:
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:0.3011200428009033
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 114.375. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [cluster1]
# INFO:pygenometracks.tracksClass:plotting 2. [spacer]
# INFO:pygenometracks.tracksClass:plotting 3. [cluster2]
# INFO:pygenometracks.tracksClass:plotting 4. [spacer]
# INFO:pygenometracks.tracksClass:plotting 5. [cluster3]
# INFO:pygenometracks.tracksClass:plotting 6. [spacer]
# INFO:pygenometracks.tracksClass:plotting 7. [cluster4]
# INFO:pygenometracks.tracksClass:plotting 8. [spacer]
# INFO:pygenometracks.tracksClass:plotting 9. [cluster5]
# INFO:pygenometracks.tracksClass:plotting 10. [spacer]
# INFO:pygenometracks.tracksClass:plotting 11. [cluster6]
# INFO:pygenometracks.tracksClass:plotting 12. [spacer]
# INFO:pygenometracks.tracksClass:plotting 13. [cluster7]
# INFO:pygenometracks.tracksClass:plotting 14. [spacer]
# ...

# %% [markdown]
# # Generate SymLinks

# %%
# for index, row in all_conf.iterrows():
for index, row in nn_snps.iterrows():
    rsid = row['rsid']
#     if os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/123_sig_list/'+rsid):
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/{rsid}.fc.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/123_sig_list/{rsid}/{rsid}.fc.1kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/{rsid}.pval.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/123_sig_list/{rsid}/{rsid}.pval.1kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/{rsid}.fc.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/123_sig_list/{rsid}/{rsid}.fc.5kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/{rsid}.pval.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/123_sig_list/{rsid}/{rsid}.pval.5kb.png
#     if os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/ryan_highlighted_figure_snps/'+rsid):
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/{rsid}.fc.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/ryan_highlighted_figure_snps/{rsid}/{rsid}.fc.1kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/{rsid}.pval.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/ryan_highlighted_figure_snps/{rsid}/{rsid}.pval.1kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/{rsid}.fc.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/ryan_highlighted_figure_snps/{rsid}/{rsid}.fc.5kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/{rsid}.pval.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/ryan_highlighted_figure_snps/{rsid}/{rsid}.pval.5kb.png
#     if os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/shared_confidence/'+rsid):
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/{rsid}.fc.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/shared_confidence/{rsid}/{rsid}.fc.1kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/{rsid}.pval.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/shared_confidence/{rsid}/{rsid}.pval.1kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/{rsid}.fc.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/shared_confidence/{rsid}/{rsid}.fc.5kb.png
#         ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/{rsid}.pval.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/shared_confidence/{rsid}/{rsid}.pval.5kb.png
    if os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/nn_hits_missed_by_svm/'+rsid):
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/{rsid}.fc.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/nn_hits_missed_by_svm/{rsid}/{rsid}.fc.1kb.png
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/{rsid}.pval.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/nn_hits_missed_by_svm/{rsid}/{rsid}.pval.1kb.png
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/{rsid}.fc.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/nn_hits_missed_by_svm/{rsid}/{rsid}.fc.5kb.png
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/{rsid}.pval.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/nn_hits_missed_by_svm/{rsid}/{rsid}.pval.5kb.png
    if os.path.isdir('/oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/10_fold_examples/nn_hits_missed_by_svm/'+rsid):
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/1kb/{rsid}.fc.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/10_fold_examples/nn_hits_missed_by_svm/{rsid}/{rsid}.fc.1kb.png
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/1kb/{rsid}.pval.1kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/10_fold_examples/nn_hits_missed_by_svm/{rsid}/{rsid}.pval.1kb.png
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_fc_signal_tracks/5kb/{rsid}.fc.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/10_fold_examples/nn_hits_missed_by_svm/{rsid}/{rsid}.fc.5kb.png
        ! ln -s /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/snp_pval_signal_tracks/5kb/{rsid}.pval.5kb.png /oak/stanford/groups/akundaje/projects/alzheimers_parkinsons/dl_svm_combined_snp_tracks/10_fold_examples/nn_hits_missed_by_svm/{rsid}/{rsid}.pval.5kb.png

# %% [markdown]
# # Final SNP Table <a name='final_table' />

# %%
all_conf.sort_values(by=['confidence','locus_num','gwas_pval'], inplace=True, ascending=False)
display(all_conf)
# Out:
#        chr      start        end         rsid effect noneffect direction  \
# 257   chr8   27369272   27369273     rs755951      A         C         -
# 256   chr8   16837908   16837909    rs1717289      T         C         -
# 367   chr7   23203210   23203211     rs858305      G         C         -
# 362   chr4   89836583   89836584    rs2619361      A         C         +
# 115   chr4     960458     960459    rs3733345      T         G         -
# 124   chr4   18002390   18002391   rs13116230      G         A         +
# 34    chr3   52498433   52498434  rs181391313      G         A         -
# 276   chr3   18177544   18177545    rs4688901      G         A         -
# 192   chr2   95074354   95074355    rs7585473      T         G         -
# 153   chr2  134719288  134719289   rs62171396      T         C         -
# 262   chr2  134782975  134782976    rs7599054      G         A         -
# 46    chr2  127128581  127128582   rs13025717      T         C         +
# ...

# %% [markdown]
# # Save Significant SNPs

# %%
all_conf.to_csv('/mnt/lab_data3/soumyak/adpd/sig_snps/all.sig.snps.atac.tracks.csv', index=False)
